# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode,iplot
init_notebook_mode(connected = True)

# %matplotlib inline
sns.set_style('whitegrid')
plt.rc('axes', titlesize = 14, titleweight = 'bold', labelweight = 'bold')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
hs = pd.read_csv('../filtered_data/04_filter_final.csv', dtype = {'LEAID':np.object})

# %%
hs.columns.values
# Out:
# array(['COMBOKEY', 'SCH_NAME', 'GSHI', 'GSLO', 'High_Grade_12', 'JJ',
#        'LAT1516', 'LEAID', 'LEA_NAME', 'LEA_STATE', 'LEA_STATE_NAME',
#        'LEVEL', 'LOCALE15', 'LON1516', 'Low_Grade_Above9', 'NMCNTY15',
#        'SCHID', 'SCH_APENR_AM_F', 'SCH_APENR_AM_M', 'SCH_APENR_AS_F',
#        'SCH_APENR_AS_M', 'SCH_APENR_BL_F', 'SCH_APENR_BL_M',
#        'SCH_APENR_HI_F', 'SCH_APENR_HI_M', 'SCH_APENR_HP_F',
#        'SCH_APENR_HP_M', 'SCH_APENR_IDEA_F', 'SCH_APENR_IDEA_M',
#        'SCH_APENR_IND', 'SCH_APENR_LEP_F', 'SCH_APENR_LEP_M',
#        'SCH_APENR_TR_F', 'SCH_APENR_TR_M', 'SCH_APENR_WH_F',
#        'SCH_APENR_WH_M', 'SCH_DUALENR_AM_F', 'SCH_DUALENR_AM_M',
#        'SCH_DUALENR_AS_F', 'SCH_DUALENR_AS_M', 'SCH_DUALENR_BL_F',
#        'SCH_DUALENR_BL_M', 'SCH_DUALENR_HI_F', 'SCH_DUALENR_HI_M',
#        'SCH_DUALENR_HP_F', 'SCH_DUALENR_HP_M', 'SCH_DUALENR_IDEA_F',
#        'SCH_DUALENR_IDEA_M', 'SCH_DUALENR_LEP_F', 'SCH_DUALENR_LEP_M',
#        'SCH_DUALENR_TR_F', 'SCH_DUALENR_TR_M', 'SCH_DUALENR_WH_F',
#        'SCH_DUALENR_WH_M', 'SCH_DUAL_IND', 'SCH_ENR_AM_F', 'SCH_ENR_AM_M',
#        'SCH_ENR_AS_F', 'SCH_ENR_AS_M', 'SCH_ENR_BL_F', 'SCH_ENR_BL_M',
#        'SCH_ENR_HI_F', 'SCH_ENR_HI_M', 'SCH_ENR_HP_F', 'SCH_ENR_HP_M',
#        'SCH_ENR_IDEA_F', 'SCH_ENR_IDEA_M', 'SCH_ENR_LEP_F',
#        'SCH_ENR_LEP_M', 'SCH_ENR_TR_F', 'SCH_ENR_TR_M', 'SCH_ENR_WH_F',
#        'SCH_ENR_WH_M', 'SCH_GRADE_G01', 'SCH_GRADE_G02', 'SCH_GRADE_G03',
#        'SCH_GRADE_G04', 'SCH_GRADE_G05', 'SCH_GRADE_G06', 'SCH_GRADE_G07',
#        'SCH_GRADE_G08', 'SCH_GRADE_G09', 'SCH_GRADE_G10', 'SCH_GRADE_G11',
#        'SCH_GRADE_G12', 'SCH_GRADE_KG', 'SCH_GRADE_PS', 'SCH_GRADE_UG',
#        'SCH_IBENR_AM_F', 'SCH_IBENR_AM_M', 'SCH_IBENR_AS_F',
#        'SCH_IBENR_AS_M', 'SCH_IBENR_BL_F', 'SCH_IBENR_BL_M',
#        'SCH_IBENR_HI_F', 'SCH_IBENR_HI_M', 'SCH_IBENR_HP_F',
#        'SCH_IBENR_HP_M', 'SCH_IBENR_IDEA_F', 'SCH_IBENR_IDEA_M',
#        'SCH_IBENR_IND', 'SCH_IBENR_LEP_F', 'SCH_IBENR_LEP_M',
#        'SCH_IBENR_TR_F', 'SCH_IBENR_TR_M', 'SCH_IBENR_WH_F',
#        'SCH_IBENR_WH_M', 'SCH_STATUS_ALT', 'SCH_STATUS_CHARTER',
#        'SCH_STATUS_MAGNET', 'SCH_STATUS_SPED', 'SCH_TYPE',
#        'SCH_TYPE_TEXT', 'SCH_UGDETAIL_HS', 'STABR', 'TITLEI',
#        'TOT_APENR_F', 'TOT_APENR_M', 'TOT_DUALENR_F', 'TOT_DUALENR_M',
#        'TOT_ENR_F', 'TOT_ENR_M', 'TOT_IBENR_F', 'TOT_IBENR_M', 'VIRTUAL',
#        'total_enrollment'], dtype=object)

# %% [markdown]
# ## Overall Breakdowns

# %% [markdown]
# **All DE**

# %%
de_breakdown = hs.groupby(['SCH_DUAL_IND'])['LEAID'].count()
print(de_breakdown)
print("")
de_pct = round(de_breakdown.iloc[1] / (de_breakdown.iloc[0] + de_breakdown.iloc[1]), 3)
print(str(de_pct) + " percent of schools in this dataset reported that they offered dual enrollment in 2013-2014.")
# Out:
# SCH_DUAL_IND
# No      4162
# Yes    11563
# Name: LEAID, dtype: int64
#
# 0.735 percent of schools in this dataset reported that they offered dual enrollment in 2013-2014.

# %% [markdown]
# **All AP**

# %%
ap_breakdown = hs.groupby(['SCH_APENR_IND'])['LEAID'].count()
print(ap_breakdown)
print("")
ap_pct = round(ap_breakdown.iloc[1] / (ap_breakdown.iloc[0] + ap_breakdown.iloc[1]), 3)
print(str(ap_pct) + " percent of schools in this dataset reported that they offered AP in 2013-2014.")
# Out:
# SCH_APENR_IND
# No      4195
# Yes    11530
# Name: LEAID, dtype: int64
#
# 0.733 percent of schools in this dataset reported that they offered AP in 2013-2014.

# %% [markdown]
# **Number of DE-Only**

# %%
de_only = len(hs[(hs['SCH_DUAL_IND'] == 'Yes') & (hs['SCH_APENR_IND'] == 'No')].index)
de_only
# Out:
# 2879

# %% [markdown]
# **Number of AP-Only**

# %%
ap_only = len(hs[(hs['SCH_DUAL_IND'] == 'No') & (hs['SCH_APENR_IND'] == 'Yes')].index)
ap_only
# Out:
# 2846

# %% [markdown]
# ** Number offering both **

# %%
de_and_ap = len(hs[((hs['SCH_DUAL_IND'] == 'Yes') & (hs['SCH_APENR_IND'] == 'Yes'))].index)
de_and_ap
# Out:
# 8684

# %% [markdown]
# **Number offering Neither**

# %%
neither = len(hs[(hs['SCH_DUAL_IND'] == 'No') & (hs['SCH_APENR_IND'] == 'No')].index)
neither
# Out:
# 1316

# %% [markdown]
# # By State

# %%
de_by_state = hs.groupby(['LEA_STATE', 'SCH_DUAL_IND'])['LEAID'].count().unstack().reset_index()
de_by_state['Total Schools'] = (de_by_state['Yes'] + de_by_state['No'])
de_by_state['pct'] = round(de_by_state['Yes'] / (de_by_state['Yes'] + de_by_state['No']), 2)

# %%
display(de_by_state.drop(['No'], axis = 1).sort_values('pct', ascending=False))
# Out:
# SCH_DUAL_IND LEA_STATE   Yes  Total Schools   pct
# 12                  IA   289            295  0.98
# 11                  HI    38             39  0.97
# 40                  SC   195            203  0.96
# 46                  VT    42             44  0.95
# 13                  ID    97            106  0.92
# 10                  GA   355            387  0.92
# 24                  MO   437            473  0.92
# 9                   FL   425            467  0.91
# 45                  VA   275            307  0.90
# 32                  NM   130            146  0.89
# 43                  TX  1054           1184  0.89
# 20                  MD   165            185  0.89
# 18                  LA   184            211  0.87
# 28                  ND   135            157  0.86
# 15                  IN   290            337  0.86
# 29                  NE   219            259  0.85
# 17                  KY   175            207  0.85
# 22                  MI   441            526  0.84
# 1                   AL   218            260  0.84
# 16                  KS   249            295  0.84
# 41                  SD   130            155  0.84
# 44                  UT   114            139  0.82
# 42                  TN   255            313  0.81
# 5                   CO   219            269  0.81
# 25                  MS   160            197  0.81
# 48                  WI   340            428  0.79
# 50                  WY    54             68  0.79
# 14                  IL   495            632  0.78
# 2                   AR   204            265  0.77
# 35                  OH   592            769  0.77
# 27                  NC   344            465  0.74
# 49                  WV    76            103  0.74
# 37                  OR   158            220  0.72
# 23                  MN   272            389  0.70
# 36                  OK   306            442  0.69
# 47                  WA   212            311  0.68
# 0                   AK    32             47  0.68
# 38                  PA   381            574  0.66
# 6                   CT   109            168  0.65
# 31                  NJ   228            350  0.65
# 21                  ME    68            106  0.64
# 8                   DE    19             30  0.63
# 30                  NH    54             90  0.60
# 26                  MT    99            167  0.59
# 39                  RI    27             49  0.55
# 3                   AZ   166            330  0.50
# 34                  NY   441            945  0.47
# 19                  MA   123            269  0.46
# 33                  NV    44             95  0.46
# 4                   CA   422           1228  0.34
# 7                   DC     6             24  0.25

# %%
de_data = dict(type = 'choropleth',
            locations = de_by_state['LEA_STATE'],
            locationmode = 'USA-states',
            colorscale = [[0.0, 'rgb(255,255,255)'], [.2, 'rgb(255,221,221)'], [.4, 'rgb(255, 200, 200)'], [0.8, 'rgb(255, 50, 50)'], [1.0, 'rgb(180,0,0)']],
            reversescale = False,
            z = de_by_state['pct'])

# %%
de_layout = dict(title = '2015-2016 DE-Offered Percentages',
              geo = {'scope':'usa'})

# %%
de_choromap = go.Figure(data = [de_data], layout = de_layout)

# %%
iplot(de_choromap)
# iplot(de_choromap, image = 'png', filename='./Visualizations/by_state_de_choropleth')
# Out:
# <div id="12df3241-0895-46e5-ba27-d14edc9a3ba3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("12df3241-0895-46e5-ba27-d14edc9a3ba3", [{"type": "choropleth", "locations": ["AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY"], "locationmode": "USA-states", "colorscale": [[0.0, "rgb(255,255,255)"], [0.2, "rgb(255,221,221)"], [0.4, "rgb(255, 200, 200)"], [0.8, "rgb(255, 50, 50)"], [1.0, "rgb(180,0,0)"]], "reversescale": false, "z": [0.68, 0.84, 0.77, 0.5, 0.34, 0.81, 0.65, 0.25, 0.63, 0.91, 0.92, 0.97, 0.98, 0.92, 0.78, 0.86, 0.84, 0.85, 0.87, 0.46, 0.89, 0.64, 0.84, 0.7, 0.92, 0.81, 0.59, 0.74, 0.86, 0.85, 0.6, 0.65, 0.89, 0.46, 0.47, 0.77, 0.69, 0.72, 0.66, 0.55, 0.96, 0.84, 0.81, 0.89, 0.82, 0.9, 0.95, 0.68, 0.79, 0.74, 0.79]}], {"title": "2015-2016 DE-Offered Percentages", "geo": {"scope": "usa"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# **AP**

# %%
ap_by_state = hs.groupby(['LEA_STATE', 'SCH_APENR_IND'])['LEAID'].count().unstack().reset_index()
"""Fill in Missing Values with 0"""
ap_by_state = ap_by_state.fillna(0)
ap_by_state[['Yes', 'No']] = ap_by_state[['Yes', 'No']].astype(int)
ap_by_state['Total Schools'] = (ap_by_state['Yes'] + ap_by_state['No'])
ap_by_state['pct'] = round(ap_by_state['Yes'] / (ap_by_state['Yes'] + ap_by_state['No']), 2)

# %%
display(ap_by_state.drop(['No'], axis = 1).sort_values('pct', ascending=False))
# Out:
# SCH_APENR_IND LEA_STATE   Yes  Total Schools   pct
# 7                    DC    24             24  1.00
# 49                   WV   100            103  0.97
# 20                   MD   176            185  0.95
# 31                   NJ   334            350  0.95
# 11                   HI    37             39  0.95
# 2                    AR   249            265  0.94
# 9                    FL   433            467  0.93
# 45                   VA   285            307  0.93
# 46                   VT    41             44  0.93
# 10                   GA   359            387  0.93
# 6                    CT   154            168  0.92
# 19                   MA   247            269  0.92
# 17                   KY   188            207  0.91
# 15                   IN   300            337  0.89
# 38                   PA   511            574  0.89
# 21                   ME    93            106  0.88
# 8                    DE    26             30  0.87
# 4                    CA  1073           1228  0.87
# 40                   SC   173            203  0.85
# 48                   WI   358            428  0.84
# 39                   RI    41             49  0.84
# 43                   TX   968           1184  0.82
# 30                   NH    73             90  0.81
# 27                   NC   373            465  0.80
# 34                   NY   749            945  0.79
# 47                   WA   246            311  0.79
# 1                    AL   194            260  0.75
# 25                   MS   146            197  0.74
# 22                   MI   389            526  0.74
# 33                   NV    70             95  0.74
# 18                   LA   153            211  0.73
# 5                    CO   191            269  0.71
# 44                   UT    97            139  0.70
# 14                   IL   424            632  0.67
# 0                    AK    30             47  0.64
# 35                   OH   476            769  0.62
# 37                   OR   129            220  0.59
# 42                   TN   186            313  0.59
# 36                   OK   238            442  0.54
# 12                   IA   160            295  0.54
# 3                    AZ   164            330  0.50
# 32                   NM    70            146  0.48
# 23                   MN   181            389  0.47
# 26                   MT    77            167  0.46
# 13                   ID    49            106  0.46
# 24                   MO   212            473  0.45
# 50                   WY    28             68  0.41
# 41                   SD    62            155  0.40
# 16                   KS    92            295  0.31
# 29                   NE    67            259  0.26
# 28                   ND    34            157  0.22

# %%
ap_data = dict(type = 'choropleth',
            locations = ap_by_state['LEA_STATE'],
            locationmode = 'USA-states',
            colorscale = [[0.0, 'rgb(255,255,255)'], [.2, 'rgb(255,221,221)'], [.4, 'rgb(255, 200, 200)'], [0.8, 'rgb(255, 50, 50)'], [1.0, 'rgb(180,0,0)']],
            reversescale = False,
            z = ap_by_state['pct'])

# %%
ap_layout = dict(title = '2015-2016 AP-Offered Percentages',
              geo = {'scope':'usa'})

# %%
ap_choromap = go.Figure(data = [ap_data], layout = ap_layout)

# %%
iplot(ap_choromap)
# iplot(ap_choromap, image = 'png', filename='./Visualizations/by_state_ap_choropleth')
# Out:
# <div id="1acd8a8a-d404-4c9a-a8e9-5b20489f58bd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1acd8a8a-d404-4c9a-a8e9-5b20489f58bd", [{"type": "choropleth", "locations": ["AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY"], "locationmode": "USA-states", "colorscale": [[0.0, "rgb(255,255,255)"], [0.2, "rgb(255,221,221)"], [0.4, "rgb(255, 200, 200)"], [0.8, "rgb(255, 50, 50)"], [1.0, "rgb(180,0,0)"]], "reversescale": false, "text": ["Home #1", "Home #2", "Home #3"], "z": [0.64, 0.75, 0.94, 0.5, 0.87, 0.71, 0.92, 1.0, 0.87, 0.93, 0.93, 0.95, 0.54, 0.46, 0.67, 0.89, 0.31, 0.91, 0.73, 0.92, 0.95, 0.88, 0.74, 0.47, 0.45, 0.74, 0.46, 0.8, 0.22, 0.26, 0.81, 0.95, 0.48, 0.74, 0.79, 0.62, 0.54, 0.59, 0.89, 0.84, 0.85, 0.4, 0.59, 0.82, 0.7, 0.93, 0.93, 0.79, 0.84, 0.97, 0.41]}], {"title": "2015-2016 AP-Offered Percentages", "geo": {"scope": "usa"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# # By Size

# %%
hs['total_enrollment'] = hs['TOT_ENR_M'] + hs['TOT_ENR_F']

# %%
def school_sizer(enroll):
    if enroll < 100:
        return 1
    elif 100 <= enroll < 500:
        return 2
    elif 500 <= enroll < 1200:
        return 3
    return 4

# %%
hs['size_group'] = hs['total_enrollment'].apply(lambda x: school_sizer(x))

# %%
sns.countplot(x = 'size_group', data = hs)
plt.title('Number of Schools in each Size Group')
plt.xticks([0,1,2,3], ['<100', '100-499', '500-1199', '>1200'])
plt.xlabel('')
# Out:
# Text(0.5,0,'')

# %% [markdown]
# **DE**

# %%
hs_by_size = hs.groupby(['size_group', 'SCH_DUAL_IND'])['LEAID'].count().unstack().reset_index()
hs_by_size['Total Schools'] = (hs_by_size['Yes'] + hs_by_size['No'])
hs_by_size['pct_de'] = round(hs_by_size['Yes'] / (hs_by_size['Yes'] + hs_by_size['No']), 2)
hs_by_size.drop(['No'], axis = 1)
# Out:
# SCH_DUAL_IND  size_group   Yes  Total Schools  pct_de
# 0                      1   607           1115    0.54
# 1                      2  4237           5802    0.73
# 2                      3  3347           4414    0.76
# 3                      4  3372           4394    0.77

# %%
hs_by_size.plot.bar(x = 'size_group', y = 'pct_de')
plt.xticks(rotation = 0)
plt.legend([])
plt.xlabel('')
plt.title('Percentage of Schools Offering DE\nBy Size ')
plt.yticks(np.arange(0,1.1,0.1))
plt.xticks([0,1,2,3], ['<100', '100-499', '500-1199', '>1200'])
plt.ylim([0,1])
# plt.savefig(fname = './Visualizations/By_Size_pct_200.png', dpi = 200)
# Out:
# (0, 1)

# %% [markdown]
# **AP**

# %%
ap_by_size = hs.groupby(['size_group', 'SCH_APENR_IND'])['LEAID'].count().unstack().reset_index()
ap_by_size['Total Schools'] = (ap_by_size['Yes'] + ap_by_size['No'])
ap_by_size['pct_ap'] = round(ap_by_size['Yes'] / (ap_by_size['Yes'] + ap_by_size['No']), 2)
ap_by_size.drop(['No'], axis = 1)
# Out:
# SCH_APENR_IND  size_group   Yes  Total Schools  pct_ap
# 0                       1   150           1115    0.13
# 1                       2  3111           5802    0.54
# 2                       3  3952           4414    0.90
# 3                       4  4317           4394    0.98

# %%
ap_by_size.plot.bar(x = 'size_group', y = 'pct_ap')
plt.xticks(rotation = 0)
plt.legend([])
plt.xlabel('')
plt.title('Percentage of Schools Offering AP\nBy Size ')
plt.yticks(np.arange(0,1.1,0.1))
plt.xticks([0,1,2,3], ['<100', '100-499', '500-1199', '>1200'])
plt.ylim([0,1])
# plt.savefig(fname = './Visualizations/By_Size_pct_200.png', dpi = 200)
# Out:
# (0, 1)

# %% [markdown]
# # By Region

# %%
"""
1:  Middle States Commission on Higher Education - New York, New Jersey, Pennsylvania, Delaware, Maryland, the District of Columbia

2:  New England Association of Schools and Colleges - Connecticut, Maine, Massachusetts, New Hampshire, Rhode Island, and Vermont

3:  Higher Learning Commission - Arkansas, Arizona, Colorado, Iowa, Illinois, Indiana, Kansas, Michigan, Minnesota, Missouri, 
    North Dakota, Nebraska, New Mexico, Ohio, Oklahoma, South Dakota, Wisconsin, West Virginia, and Wyoming

4:  Northwest Commission on Colleges and Universities - Alaska, Idaho, Montana, Nevada, Oregon, Utah, and Washington

5:  Southern Association of Colleges and Schools - Alabama, Florida, Georgia, Kentucky, Louisiana, Mississippi, 
    North Carolina, South Carolina, Tennessee, Texas and Virginia

6:  Western Association of Schools and Colleges - California, Hawaii
"""

middle_states = "NY,NJ,PA,DE,MD,DC".split(',')
new_england = "CT,ME,MA,NH,RI,VT".split(',')
higher_learning_commission = "AR,AZ,CO,IA,IL,IN,KS,MI,MN,MO,ND,NE,NM,OH,OK,SD,WI,WV,WY".split(',')
northwest_commission = "AK,ID,MT,NV,OR,UT,WA".split(',')
southern_association = "AL,FL,GA,KY,LA,MS,NC,SC,TN,TX,VA".split(',')
western_association = "CA,HI".split(',')

# %%
def region_mapper(state):
    if state in middle_states:
        return "MSCHE"
    elif state in new_england:
        return "NEASC"
    elif state in higher_learning_commission:
        return "HLC"
    elif state in northwest_commission:
        return "NWCCU"
    elif state in southern_association:
        return "SACS"
    elif state in western_association:
        return "WASC"
    else:
        return "Messed Up"
    
hs['region_accred'] = hs['LEA_STATE'].apply(lambda x: region_mapper(x))

# %%
sns.lmplot(x = 'LON1516', y = 'LAT1516', data = hs, hue = 'region_accred', fit_reg = False, aspect = 1.2)
# plt.savefig(fname = './Visualizations/By_regionII_map_200.png', dpi = 200)

# %% [markdown]
# **DE**

# %%
de_by_region_accred = hs.groupby(['region_accred', 'SCH_DUAL_IND'])['LEA_STATE'].count().unstack('SCH_DUAL_IND').reset_index()
de_by_region_accred['Total Schools'] = (de_by_region_accred['Yes'] + de_by_region_accred['No'])
de_by_region_accred['pct_de'] = round(de_by_region_accred['Yes'] / (de_by_region_accred['Yes'] + de_by_region_accred['No']), 2)
de_by_region_accred.drop(['No'], axis = 1)
# Out:
# SCH_DUAL_IND region_accred   Yes  Total Schools  pct_de
# 0                      HLC  5044           6338    0.80
# 1                    MSCHE  1240           2108    0.59
# 2                    NEASC   423            726    0.58
# 3                    NWCCU   756           1085    0.70
# 4                     SACS  3640           4201    0.87
# 5                     WASC   460           1267    0.36

# %%
g = de_by_region_accred.plot.bar(x = 'region_accred', y = 'pct_de')

plt.title('Percentage of Schools Offering DE\n by Region')
plt.xticks(rotation = 0)
plt.legend([])
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')

# plt.savefig(fname = './Visualizations/By_regionII_pct_200.png', dpi = 200)
# Out:
# Text(0.5,0,'')

# %% [markdown]
# **AP**

# %%
ap_by_region_accred = hs.groupby(['region_accred', 'SCH_APENR_IND'])['LEA_STATE'].count().unstack().reset_index()
ap_by_region_accred['Total Schools'] = (ap_by_region_accred['Yes'] + ap_by_region_accred['No'])
ap_by_region_accred['pct_ap'] = round(ap_by_region_accred['Yes'] / (ap_by_region_accred['Yes'] + ap_by_region_accred['No']), 2)
ap_by_region_accred.drop(['No'], axis = 1)
# Out:
# SCH_APENR_IND region_accred   Yes  Total Schools  pct_ap
# 0                       HLC  3795           6338    0.60
# 1                     MSCHE  1820           2108    0.86
# 2                     NEASC   649            726    0.89
# 3                     NWCCU   698           1085    0.64
# 4                      SACS  3458           4201    0.82
# 5                      WASC  1110           1267    0.88

# %%
g = ap_by_region_accred.plot.bar(x = 'region_accred', y = 'pct_ap')

plt.title('Percentage of Schools Offering AP\n by Region')
plt.xticks(rotation = 0)
plt.legend([])
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')

# plt.savefig(fname = './Visualizations/By_regionII_pct_200.png', dpi = 200)
# Out:
# Text(0.5,0,'')

# %% [markdown]
# # By Locale

# %%
locale_map = {11: 'City', 12: 'City', 13: 'City', 14: 'City',
              21: 'Suburban', 22: 'Suburban', 23: 'Suburban', 24: 'Suburban',
              31: 'Town', 32: 'Town', 33: 'Town', 34: 'Town',
              41: 'Rural', 42: 'Rural', 43: 'Rural', 44: 'Rural'}

hs['locale_group'] = hs['LOCALE15'].map(locale_map)

# %% [markdown]
# **DE**

# %%
de_by_locale = hs.groupby(['locale_group', 'SCH_DUAL_IND'])['LEA_STATE'].count().unstack('SCH_DUAL_IND').reset_index()
de_by_locale['Total Schools'] = (de_by_locale['Yes'] + de_by_locale['No'])
de_by_locale['pct_de'] = round(de_by_locale['Yes'] / (de_by_locale['Yes'] + de_by_locale['No']), 2)
de_by_locale.drop(['No'], axis = 1)
# Out:
# SCH_DUAL_IND locale_group   Yes  Total Schools  pct_de
# 0                    City  1976           3347    0.59
# 1                   Rural  4782           5935    0.81
# 2                Suburban  2888           4046    0.71
# 3                    Town  1917           2397    0.80

# %%
g = de_by_locale.plot.bar(x = 'locale_group', y = 'pct_de')
plt.title('Percentage of Schools Offering DE\n by Locale')
plt.xticks(rotation = 0)
plt.legend([])
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')
# plt.savefig(fname = './Visualizations/By_locale_pc_200.png', dpi = 200)
# Out:
# Text(0.5,0,'')

# %% [markdown]
# **AP**

# %%
ap_by_locale = hs.groupby(['locale_group', 'SCH_APENR_IND'])['LEA_STATE'].count().unstack().reset_index()
ap_by_locale['Total Schools'] = (ap_by_locale['Yes'] + ap_by_locale['No'])
ap_by_locale['pct_ap'] = round(ap_by_locale['Yes'] / (ap_by_locale['Yes'] + ap_by_locale['No']), 2)
ap_by_locale.drop(['No'], axis = 1)
# Out:
# SCH_APENR_IND locale_group   Yes  Total Schools  pct_ap
# 0                     City  2675           3347    0.80
# 1                    Rural  3382           5935    0.57
# 2                 Suburban  3700           4046    0.91
# 3                     Town  1773           2397    0.74

# %%
g = ap_by_locale.plot.bar(x = 'locale_group', y = 'pct_ap')
plt.title('Percentage of Schools Offering AP\n by Locale')
plt.xticks(rotation = 0)
plt.legend([])
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')
# plt.savefig(fname = './Visualizations/By_locale_pc_200.png', dpi = 200)
# Out:
# Text(0.5,0,'')

# %% [markdown]
# # By Charter

# %%
hs.SCH_STATUS_CHARTER.value_counts()
# Out:
# No     14729
# Yes      996
# Name: SCH_STATUS_CHARTER, dtype: int64

# %% [markdown]
# **DE**

# %%
de_by_charter = hs.groupby(['SCH_STATUS_CHARTER', 'SCH_DUAL_IND'])['LEAID'].count().unstack().reset_index()
de_by_charter['SCH_STATUS_CHARTER'] = de_by_charter['SCH_STATUS_CHARTER'].map({'No':'Regular', 'Yes':'Charter'})
de_by_charter['Total Schools'] = (de_by_charter['No'] + de_by_charter['Yes'])
de_by_charter['pct_de'] = round(de_by_charter['Yes'] / (de_by_charter['No'] + de_by_charter['Yes']), 2)
de_by_charter.drop(['No'], axis = 1)
# Out:
# SCH_DUAL_IND SCH_STATUS_CHARTER    Yes  Total Schools  pct_de
# 0                       Regular  11143          14729    0.76
# 1                       Charter    420            996    0.42

# %%
de_by_charter.plot.bar(x = 'SCH_STATUS_CHARTER', y = 'pct_de')
plt.legend([])
plt.title('Percentage of Schools with DE\nBy Charter Status')
plt.xticks(rotation = 0)
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')
# plt.savefig(fname = './Visualizations/By_charter_pct_200.png', dpi = 200)
# Out:
# Text(0.5,0,'')

# %% [markdown]
# **AP**

# %%
ap_by_charter = hs.groupby(['SCH_STATUS_CHARTER', 'SCH_APENR_IND'])['LEAID'].count().unstack().reset_index()
ap_by_charter['SCH_STATUS_CHARTER'] = ap_by_charter['SCH_STATUS_CHARTER'].map({'No':'Regular', 'Yes':'Charter'})
ap_by_charter['Total Schools'] = (ap_by_charter['No'] + ap_by_charter['Yes'])
ap_by_charter['pct_ap'] = round(ap_by_charter['Yes'] / (ap_by_charter['No'] + ap_by_charter['Yes']), 2)
ap_by_charter.drop(['No'], axis = 1)
# Out:
# SCH_APENR_IND SCH_STATUS_CHARTER    Yes  Total Schools  pct_ap
# 0                        Regular  11098          14729    0.75
# 1                        Charter    432            996    0.43

# %%
ap_by_charter.plot.bar(x = 'SCH_STATUS_CHARTER', y = 'pct_ap')
plt.legend([])
plt.title('Percentage of Schools with AP\nBy Charter Status')
plt.xticks(rotation = 0)
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')
# plt.savefig(fname = './Visualizations/By_charter_pct_200.png', dpi = 200)
# Out:
# Text(0.5,0,'')

# %% [markdown]
# # Title I Eligibility

# %%
hs.TITLEI.value_counts()
# Out:
# Yes               9862
# No                5524
# -9                 260
# Missing             73
# Not Applicable       6
# Name: TITLEI, dtype: int64

# %%
"""Remove the Misreported/Null Values"""
hs_by_titleI = hs.drop(hs[(hs.TITLEI == 'Missing') | (hs.TITLEI == 'Not Applicable') | (hs.TITLEI == '-9')].index, axis = 0)
hs_by_titleI.TITLEI.value_counts()
# Out:
# Yes    9862
# No     5524
# Name: TITLEI, dtype: int64

# %% [markdown]
# **DE**

# %%
de_by_titleI = hs_by_titleI.groupby(['TITLEI', 'SCH_DUAL_IND'])['LEAID'].count().unstack().reset_index()
de_by_titleI['TITLEI'] = de_by_titleI['TITLEI'].map({'Yes':'Eligible', 'No':'Not Eligible'})
de_by_titleI['Total Schools'] = (de_by_titleI['No'] + de_by_titleI['Yes'])
de_by_titleI['pct_de'] = round(de_by_titleI['Yes'] / (de_by_titleI['No'] + de_by_titleI['Yes']), 2)
de_by_titleI.drop(['No'], axis = 1)
# Out:
# SCH_DUAL_IND        TITLEI   Yes  Total Schools  pct_de
# 0             Not Eligible  4207           5524    0.76
# 1                 Eligible  7113           9862    0.72

# %%
de_by_titleI.plot.bar(x = 'TITLEI', y = 'pct_de')
plt.legend([])
plt.title('Percentage of Schools with DE\nBy Title I Eligibility')
plt.xticks(rotation = 0)
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')
# plt.savefig(fname = './Visualizations/By_titleI_pct_200.png', dpi = 200)
# Out:
# Text(0.5,0,'')

# %% [markdown]
# **AP**

# %%
ap_by_titleI = hs_by_titleI.groupby(['TITLEI', 'SCH_APENR_IND'])['LEAID'].count().unstack().reset_index()
ap_by_titleI['TITLEI'] = ap_by_titleI['TITLEI'].map({'Yes':'Eligible', 'No':'Not Eligible'})
ap_by_titleI['Total Schools'] = (ap_by_titleI['No'] + ap_by_titleI['Yes'])
ap_by_titleI['pct_ap'] = round(ap_by_titleI['Yes'] / (ap_by_titleI['No'] + ap_by_titleI['Yes']), 2)
ap_by_titleI.drop(['No'], axis = 1)
# Out:
# SCH_APENR_IND        TITLEI   Yes  Total Schools  pct_ap
# 0              Not Eligible  4312           5524    0.78
# 1                  Eligible  6978           9862    0.71

# %%
ap_by_titleI.plot.bar(x = 'TITLEI', y = 'pct_ap')
plt.legend([])
plt.title('Percentage of Schools with AP\nBy Title I Eligibility')
plt.xticks(rotation = 0)
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')
# plt.savefig(fname = './Visualizations/By_titleI_pct_200.png', dpi = 200)
# Out:
# Text(0.5,0,'')

# %% [markdown]
# # Ethnicity Quintiles

# %%
hs['pct_eth'] = (hs['total_enrollment'] - hs['SCH_ENR_WH_F'] - hs['SCH_ENR_WH_M']) / hs['total_enrollment']

# %%
hs.pct_eth.plot.hist(bins=100, xlim = [0,1], edgecolor = 'k')
plt.title('Distribution of Schools by Ethnicity Percentages')
plt.xlabel('Ethnicity Percentage')
# plt.savefig(fname = './Visualizations/By_ethnicity_dist_200.png', dpi = 200)
# Out:
# Text(0.5,0,'Ethnicity Percentage')

# %%
def eth_grouper(pct):
    if pct <= .20:
        return 1
    elif .20 < pct <= .4:
        return 2
    elif .4 < pct <= 0.6:
        return 3
    elif .6 < pct <= .8:
        return 4
    return 5
    
hs['eth_quintile'] = hs['pct_eth'].apply(lambda pct: eth_grouper(pct))

# %% [markdown]
# **DE**

# %%
hs_by_eth_quin = hs.groupby(['eth_quintile', 'SCH_DUAL_IND'])['LEAID'].count().unstack().reset_index()
hs_by_eth_quin['Total Schools'] = (hs_by_eth_quin['No'] + hs_by_eth_quin['Yes'])
hs_by_eth_quin['pct_de'] = round(hs_by_eth_quin['Yes'] / (hs_by_eth_quin['No'] + hs_by_eth_quin['Yes']), 2)
display(hs_by_eth_quin.drop(['No'], axis = 1))
# Out:
# SCH_DUAL_IND  eth_quintile   Yes  Total Schools  pct_de
# 0                        1  4940           6099    0.81
# 1                        2  2316           2967    0.78
# 2                        3  1545           2059    0.75
# 3                        4  1050           1547    0.68
# 4                        5  1712           3053    0.56

# %%
hs_by_eth_quin.plot.bar(x = 'eth_quintile', y = 'pct_de')
plt.legend([])
plt.title('Percentage of Schools with DE\nBy Ethnicity Percentage Quintiles')
plt.xticks(rotation = 0)
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xticks([0,1,2,3,4], ['0-20%', '21-40%', '41-60%', '61-80%', '81-100%'])
plt.xlabel('')
# plt.savefig(fname = './Visualizations/By_ethnicity_quint_pct_200.png', dpi = 200)
# Out:
# Text(0.5,0,'')

# %% [markdown]
# **AP**

# %%
ap_by_eth_quin = hs.groupby(['eth_quintile', 'SCH_APENR_IND'])['LEAID'].count().unstack().reset_index()
ap_by_eth_quin['Total Schools'] = (ap_by_eth_quin['No'] + ap_by_eth_quin['Yes'])
ap_by_eth_quin['pct_ap'] = round(ap_by_eth_quin['Yes'] / (ap_by_eth_quin['No'] + ap_by_eth_quin['Yes']), 2)
display(ap_by_eth_quin.drop(['No'], axis = 1))
# Out:
# SCH_APENR_IND  eth_quintile   Yes  Total Schools  pct_ap
# 0                         1  4014           6099    0.66
# 1                         2  2298           2967    0.77
# 2                         3  1673           2059    0.81
# 3                         4  1240           1547    0.80
# 4                         5  2305           3053    0.75

# %%
ap_by_eth_quin.plot.bar(x = 'eth_quintile', y = 'pct_ap')
plt.legend([])
plt.title('Percentage of Schools with AP\nBy Ethnicity Percentage Quintiles')
plt.xticks(rotation = 0)
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xticks([0,1,2,3,4], ['0-20%', '21-40%', '41-60%', '61-80%', '81-100%'])
plt.xlabel('')
# plt.savefig(fname = './Visualizations/By_ethnicity_quint_pct_200.png', dpi = 200)
# Out:
# Text(0.5,0,'')

# %% [markdown]
# **Ethnicity Exploration**

# %%
"""States with the highest number of 98%+ non-white schools (top 10)"""
hs[hs.pct_eth >= 0.98].groupby('LEA_STATE')['LEAID'].count().sort_values(ascending = False).head(10)
# Out:
# LEA_STATE
# CA    174
# NY    153
# TX    148
# IL     70
# GA     43
# NJ     39
# MI     36
# MS     36
# AZ     32
# TN     30
# Name: LEAID, dtype: int64

# %% [markdown]
# # By District

# %% [markdown]
# **DE**

# %%
hs_by_district = hs.groupby(['LEAID', 'LEA_NAME', 'LEA_STATE', 'SCH_DUAL_IND'])['LEAID'].count().unstack().reset_index()
hs_by_district = hs_by_district.fillna(0)
hs_by_district[['No', 'Yes']] = hs_by_district[['No', 'Yes']].astype(int)

hs_by_district['Total Schools'] = (hs_by_district['No'] + hs_by_district['Yes'])
hs_by_district['pct_de'] = round(hs_by_district['Yes'] / (hs_by_district['No'] + hs_by_district['Yes']), 2)

# %%
with pd.option_context('display.max_rows', 100):
    display(hs_by_district.drop(['No'], axis = 1).sort_values('Total Schools', ascending = False).reset_index().drop(['index'], axis = 1).head(100))
# Out:
# SCH_DUAL_IND    LEAID                                           LEA_NAME  \
# 0             3620580                       NEW YORK CITY PUBLIC SCHOOLS
# 1              622710                                Los Angeles Unified
# 2             1709930                             City of Chicago SD 299
# 3             1200390                                               DADE
# 4             3200060                       CLARK COUNTY SCHOOL DISTRICT
# 5             4700148                              Shelby County Schools
# 6             1500030                     Hawaii Department of Education
# 7             4823640                                        HOUSTON ISD
# 8             4218990                               Philadelphia City SD
# 9             4816230                                         DALLAS ISD
# 10            1200180                                            BROWARD
# 11             634320                                  San Diego Unified
# 12            1200870                                       HILLSBOROUGH
# 13            1201500                                         PALM BEACH
# 14            3701920                            Guilford County Schools
# 15            3702970                      Charlotte-Mecklenburg Schools
# 16            2400480                   Montgomery County Public Schools
# 17            5101260                               FAIRFAX CO PBLC SCHS
# 18            3704720                                Wake County Schools
# 19            3904378             Cleveland Metropolitan School District
# 20            2400510              Prince George's County Public Schools
# 21            1201440                                             ORANGE
# 22            1200480                                              DUVAL
# 23            1301740                                      DeKalb County
# 24            2400120                    Baltimore County Public Schools
# 25             804800           Jefferson County School District No. R-1
# 26            1302550                                    Gwinnett County
# 27            4703180                                    Davidson County
# 28             619540                                          Kern High
# 29             803360  School District No. 1 in the county of Denver ...
# 30            1201560                                           PINELLAS
# 31            2102990                                   Jefferson County
# 32            2400090                      Baltimore City Public Schools
# 33            5509600                          Milwaukee School District
# 34            4702220                                        Knox County
# 35            4502310                                      Greenville 01
# 36            3904380                      Columbus City School District
# 37            1302280                                      Fulton County
# 38            2612000                       Detroit City School District
# 39            2502790                                             Boston
# 40            3200480                      WASHOE COUNTY SCHOOL DISTRICT
# 41            1201080                                                LEE
# 42            1200150                                            BREVARD
# 43            1301290                                        Cobb County
# 44            1201590                                               POLK
# 45            4819700                                     FORT WORTH ISD
# 46            3700011                          Cumberland County Schools
# 47            1300120                             Atlanta Public Schools
# 48            2200540                            East Baton Rouge Parish
# 49            3411340                      NEWARK PUBLIC SCHOOL DISTRICT
# 50            3500060                         ALBUQUERQUE PUBLIC SCHOOLS
# 51            3701500               Winston Salem/Forsyth County Schools
# 52             638640                              Sweetwater Union High
# 53            1100030                District of Columbia Public Schools
# 54            4701590                                    Hamilton County
# 55            5307710                             Seattle Public Schools
# 56            3624750                     ROCHESTER CITY SCHOOL DISTRICT
# 57             406330                 Phoenix Union High School District
# 58            2400420                       Howard County Public Schools
# 59             102370                                      Mobile County
# 60            5103840                            VA BEACH CITY PBLC SCHS
# 61            4808940                                         AUSTIN ISD
# 62            2400060                 Anne Arundel County Public Schools
# 63            4818300                                        EL PASO ISD
# 64             901920                           HARTFORD SCHOOL DISTRICT
# 65            1301020                                             SCCPSS
# 66            5103130                        PRINCE WILLIAM CO PBLC SCHS
# 67             611820               East Side Union High School District
# 68            3904375                                    Cincinnati City
# 69             616230                               Grossmont Union High
# 70            4819650                                      FORT BEND ISD
# 71            3704620                        Union County Public Schools
# 72            06CC366                           Green Dot Public Schools
# 73            3701620                              Gaston County Schools
# 74            2929280                                     ST. LOUIS CITY
# 75            4833120                                      NORTHSIDE ISD
# 76            1201530                                              PASCO
# 77             101920                                   Jefferson County
# 78            4501440                                      Charleston 01
# 79            4022770                                      OKLAHOMA CITY
# 80            2400330                    Frederick County Public Schools
# 81            1304380                                    Richmond County
# 82             633840                            Sacramento City Unified
# 83             634410                              San Francisco Unified
# 84            5100840                          CHESTERFIELD CO PBLC SCHS
# 85            4502490                                           Horry 01
# 86            4816110                              CYPRESS-FAIRBANKS ISD
# 87            2200840                                   Jefferson Parish
# 88            1301230                                     Clayton County
# 89             408800                            Tucson Unified District
# 90            1302820                                       Henry County
# 91            3412690                    Paterson Public School District
# 92             612330                                  Elk Grove Unified
# 93             622500                                 Long Beach Unified
# 94            1303870                                    Muscogee County
# 95            4704530                          Williamson County Schools
# 96            1201260                                             MARION
# 97            1201920                                            VOLUSIA
# 98            4704020                                      Sumner County
# 99             803450            Douglas County School District No. Re 1
#
# SCH_DUAL_IND LEA_STATE  Yes  Total Schools  pct_de
# 0                   NY   94            347    0.27
# 1                   CA   60            105    0.57
# 2                   IL   70             97    0.72
# 3                   FL   60             77    0.78
# 4                   NV    9             46    0.20
# 5                   TN   24             40    0.60
# 6                   HI   38             39    0.97
# 7                   TX   29             38    0.76
# 8                   PA    0             37    0.00
# 9                   TX   26             35    0.74
# 10                  FL   33             35    0.94
# 11                  CA    7             30    0.23
# 12                  FL   20             29    0.69
# 13                  FL   25             28    0.89
# 14                  NC   26             27    0.96
# 15                  NC   23             26    0.88
# 16                  MD   25             25    1.00
# 17                  VA   16             25    0.64
# 18                  NC   10             24    0.42
# 19                  OH    0             24    0.00
# 20                  MD   22             23    0.96
# 21                  FL   21             22    0.95
# 22                  FL   19             22    0.86
# 23                  GA   16             21    0.76
# 24                  MD   21             21    1.00
# 25                  CO   21             21    1.00
# 26                  GA   18             20    0.90
# 27                  TN    4             19    0.21
# 28                  CA    0             19    0.00
# 29                  CO   10             19    0.53
# 30                  FL   17             18    0.94
# 31                  KY   12             18    0.67
# 32                  MD    1             18    0.06
# 33                  WI   14             18    0.78
# 34                  TN   14             17    0.82
# 35                  SC   15             17    0.88
# 36                  OH   17             17    1.00
# 37                  GA   16             16    1.00
# 38                  MI    1             16    0.06
# 39                  MA    0             16    0.00
# 40                  NV    9             16    0.56
# 41                  FL   15             16    0.94
# 42                  FL   16             16    1.00
# 43                  GA   16             16    1.00
# 44                  FL   15             15    1.00
# 45                  TX   15             15    1.00
# 46                  NC   14             14    1.00
# 47                  GA   10             14    0.71
# 48                  LA    2             13    0.15
# 49                  NJ    9             13    0.69
# 50                  NM    6             13    0.46
# 51                  NC    0             13    0.00
# 52                  CA   11             13    0.85
# 53                  DC    1             13    0.08
# 54                  TN    8             12    0.67
# 55                  WA    6             12    0.50
# 56                  NY    4             12    0.33
# 57                  AZ   11             12    0.92
# 58                  MD   12             12    1.00
# 59                  AL   12             12    1.00
# 60                  VA   11             12    0.92
# 61                  TX    8             12    0.67
# 62                  MD   12             12    1.00
# 63                  TX   12             12    1.00
# 64                  CT    4             11    0.36
# 65                  GA    7             11    0.64
# 66                  VA   11             11    1.00
# 67                  CA    2             11    0.18
# 68                  OH   10             11    0.91
# 69                  CA    1             11    0.09
# 70                  TX   11             11    1.00
# 71                  NC   10             11    0.91
# 72                  CA    0             11    0.00
# 73                  NC    0             11    0.00
# 74                  MO    9             11    0.82
# 75                  TX   11             11    1.00
# 76                  FL   11             11    1.00
# 77                  AL    8             10    0.80
# 78                  SC    9             10    0.90
# 79                  OK    8             10    0.80
# 80                  MD   10             10    1.00
# 81                  GA    7             10    0.70
# 82                  CA    0             10    0.00
# 83                  CA    1             10    0.10
# 84                  VA    8             10    0.80
# 85                  SC    9             10    0.90
# 86                  TX   10             10    1.00
# 87                  LA    8             10    0.80
# 88                  GA   10             10    1.00
# 89                  AZ    3             10    0.30
# 90                  GA   10             10    1.00
# 91                  NJ    2             10    0.20
# 92                  CA    9              9    1.00
# 93                  CA    2              9    0.22
# 94                  GA    8              9    0.89
# 95                  TN    9              9    1.00
# 96                  FL    8              9    0.89
# 97                  FL    9              9    1.00
# 98                  TN    9              9    1.00
# 99                  CO    9              9    1.00

# %%
"""Distribution of DE-Offering Percentages sorted by largest to smallest districts (top 100), so left-x-axis have the
largest districts, and right-x-axis have the smallest."""
plt.figure(figsize=(10,4))
hs_by_district.drop(['No'], axis = 1).sort_values('Total Schools', ascending = False).reset_index().drop(['index'], axis = 1).head(100)['pct_de'].plot.bar()
plt.xticks([])
plt.title('DE-Offering Percentages of the Top 100 Districts')
# Out:
# Text(0.5,1,'DE-Offering Percentages of the Top 100 Districts')

# %%
"""Distribution of De-Offering % of the top 100 schools (no proper order), looks like 8 districts have 0%"""
plt.figure(figsize=(10,4))
hs_by_district.drop(['No'], axis = 1).sort_values(['Total Schools'], ascending = False).reset_index().drop(['index'], axis = 1).head(100).sort_values('pct_de', ascending = False)['pct_de'].plot.bar()
plt.title('DE-Offering Percentages of the Top 100 Districts')
# Out:
# Text(0.5,1,'DE-Offering Percentages of the Top 100 Districts')

# %%
hs_by_district.drop(['No'], axis = 1).sort_values(['Total Schools'], ascending = False).reset_index().drop(['index'], axis = 1).head(100).sort_values('pct_de', ascending = False)
# Out:
# SCH_DUAL_IND    LEAID                                           LEA_NAME  \
# 99             803450            Douglas County School District No. Re 1
# 45            4819700                                     FORT WORTH ISD
# 92             612330                                  Elk Grove Unified
# 90            1302820                                       Henry County
# 88            1301230                                     Clayton County
# 36            3904380                      Columbus City School District
# 86            4816110                              CYPRESS-FAIRBANKS ISD
# 42            1200150                                            BREVARD
# 43            1301290                                        Cobb County
# 44            1201590                                               POLK
# 46            3700011                          Cumberland County Schools
# 24            2400120                    Baltimore County Public Schools
# 80            2400330                    Frederick County Public Schools
# 58            2400420                       Howard County Public Schools
# 59             102370                                      Mobile County
# 62            2400060                 Anne Arundel County Public Schools
# 63            4818300                                        EL PASO ISD
# 66            5103130                        PRINCE WILLIAM CO PBLC SCHS
# 70            4819650                                      FORT BEND ISD
# 76            1201530                                              PASCO
# 25             804800           Jefferson County School District No. R-1
# 37            1302280                                      Fulton County
# 75            4833120                                      NORTHSIDE ISD
# 95            4704530                          Williamson County Schools
# 16            2400480                   Montgomery County Public Schools
# 97            1201920                                            VOLUSIA
# 98            4704020                                      Sumner County
# 6             1500030                     Hawaii Department of Education
# 14            3701920                            Guilford County Schools
# 20            2400510              Prince George's County Public Schools
# ..                ...                                                ...
# 1              622710                                Los Angeles Unified
# 40            3200480                      WASHOE COUNTY SCHOOL DISTRICT
# 29             803360  School District No. 1 in the county of Denver ...
# 55            5307710                             Seattle Public Schools
# 50            3500060                         ALBUQUERQUE PUBLIC SCHOOLS
# 18            3704720                                Wake County Schools
# 64             901920                           HARTFORD SCHOOL DISTRICT
# 56            3624750                     ROCHESTER CITY SCHOOL DISTRICT
# 89             408800                            Tucson Unified District
# 0             3620580                       NEW YORK CITY PUBLIC SCHOOLS
# 11             634320                                  San Diego Unified
# 93             622500                                 Long Beach Unified
# 27            4703180                                    Davidson County
# 91            3412690                    Paterson Public School District
# 4             3200060                       CLARK COUNTY SCHOOL DISTRICT
# 67             611820               East Side Union High School District
# 48            2200540                            East Baton Rouge Parish
# 83             634410                              San Francisco Unified
# 69             616230                               Grossmont Union High
# 53            1100030                District of Columbia Public Schools
# 38            2612000                       Detroit City School District
# 32            2400090                      Baltimore City Public Schools
# 28             619540                                          Kern High
# 72            06CC366                           Green Dot Public Schools
# 19            3904378             Cleveland Metropolitan School District
# 39            2502790                                             Boston
# 51            3701500               Winston Salem/Forsyth County Schools
# 8             4218990                               Philadelphia City SD
# 82             633840                            Sacramento City Unified
# 73            3701620                              Gaston County Schools
#
# SCH_DUAL_IND LEA_STATE  Yes  Total Schools  pct_de
# 99                  CO    9              9    1.00
# 45                  TX   15             15    1.00
# 92                  CA    9              9    1.00
# 90                  GA   10             10    1.00
# 88                  GA   10             10    1.00
# 36                  OH   17             17    1.00
# 86                  TX   10             10    1.00
# 42                  FL   16             16    1.00
# 43                  GA   16             16    1.00
# 44                  FL   15             15    1.00
# 46                  NC   14             14    1.00
# 24                  MD   21             21    1.00
# 80                  MD   10             10    1.00
# 58                  MD   12             12    1.00
# 59                  AL   12             12    1.00
# 62                  MD   12             12    1.00
# 63                  TX   12             12    1.00
# 66                  VA   11             11    1.00
# 70                  TX   11             11    1.00
# 76                  FL   11             11    1.00
# 25                  CO   21             21    1.00
# 37                  GA   16             16    1.00
# 75                  TX   11             11    1.00
# 95                  TN    9              9    1.00
# 16                  MD   25             25    1.00
# 97                  FL    9              9    1.00
# 98                  TN    9              9    1.00
# 6                   HI   38             39    0.97
# 14                  NC   26             27    0.96
# 20                  MD   22             23    0.96
# ..                 ...  ...            ...     ...
# 1                   CA   60            105    0.57
# 40                  NV    9             16    0.56
# 29                  CO   10             19    0.53
# 55                  WA    6             12    0.50
# 50                  NM    6             13    0.46
# 18                  NC   10             24    0.42
# 64                  CT    4             11    0.36
# 56                  NY    4             12    0.33
# 89                  AZ    3             10    0.30
# 0                   NY   94            347    0.27
# 11                  CA    7             30    0.23
# 93                  CA    2              9    0.22
# 27                  TN    4             19    0.21
# 91                  NJ    2             10    0.20
# 4                   NV    9             46    0.20
# 67                  CA    2             11    0.18
# 48                  LA    2             13    0.15
# 83                  CA    1             10    0.10
# 69                  CA    1             11    0.09
# 53                  DC    1             13    0.08
# 38                  MI    1             16    0.06
# 32                  MD    1             18    0.06
# 28                  CA    0             19    0.00
# 72                  CA    0             11    0.00
# 19                  OH    0             24    0.00
# 39                  MA    0             16    0.00
# 51                  NC    0             13    0.00
# 8                   PA    0             37    0.00
# 82                  CA    0             10    0.00
# 73                  NC    0             11    0.00
#
# [100 rows x 6 columns]

# %% [markdown]
# **AP**

# %%
ap_by_district = hs.groupby(['LEAID', 'LEA_NAME', 'LEA_STATE', 'SCH_APENR_IND'])['LEAID'].count().unstack().reset_index()
ap_by_district = ap_by_district.fillna(0)
ap_by_district[['No', 'Yes']] = ap_by_district[['No', 'Yes']].astype(int)

ap_by_district['Total Schools'] = (ap_by_district['No'] + ap_by_district['Yes'])
ap_by_district['pct_ap'] = round(ap_by_district['Yes'] / (ap_by_district['No'] + ap_by_district['Yes']), 2)

# %%
with pd.option_context('display.max_rows', 100):
    display(ap_by_district.drop(['No'], axis = 1).sort_values('Total Schools', ascending = False).reset_index().drop(['index'], axis = 1).head(100))
# Out:
# SCH_APENR_IND    LEAID                                           LEA_NAME  \
# 0              3620580                       NEW YORK CITY PUBLIC SCHOOLS
# 1               622710                                Los Angeles Unified
# 2              1709930                             City of Chicago SD 299
# 3              1200390                                               DADE
# 4              3200060                       CLARK COUNTY SCHOOL DISTRICT
# 5              4700148                              Shelby County Schools
# 6              1500030                     Hawaii Department of Education
# 7              4823640                                        HOUSTON ISD
# 8              4218990                               Philadelphia City SD
# 9              4816230                                         DALLAS ISD
# 10             1200180                                            BROWARD
# 11              634320                                  San Diego Unified
# 12             1200870                                       HILLSBOROUGH
# 13             1201500                                         PALM BEACH
# 14             3701920                            Guilford County Schools
# 15             3702970                      Charlotte-Mecklenburg Schools
# 16             2400480                   Montgomery County Public Schools
# 17             5101260                               FAIRFAX CO PBLC SCHS
# 18             3704720                                Wake County Schools
# 19             3904378             Cleveland Metropolitan School District
# 20             2400510              Prince George's County Public Schools
# 21             1201440                                             ORANGE
# 22             1200480                                              DUVAL
# 23             1301740                                      DeKalb County
# 24             2400120                    Baltimore County Public Schools
# 25              804800           Jefferson County School District No. R-1
# 26             1302550                                    Gwinnett County
# 27             4703180                                    Davidson County
# 28              619540                                          Kern High
# 29              803360  School District No. 1 in the county of Denver ...
# 30             1201560                                           PINELLAS
# 31             2102990                                   Jefferson County
# 32             2400090                      Baltimore City Public Schools
# 33             5509600                          Milwaukee School District
# 34             4702220                                        Knox County
# 35             4502310                                      Greenville 01
# 36             3904380                      Columbus City School District
# 37             1302280                                      Fulton County
# 38             2612000                       Detroit City School District
# 39             2502790                                             Boston
# 40             3200480                      WASHOE COUNTY SCHOOL DISTRICT
# 41             1201080                                                LEE
# 42             1200150                                            BREVARD
# 43             1301290                                        Cobb County
# 44             1201590                                               POLK
# 45             4819700                                     FORT WORTH ISD
# 46             3700011                          Cumberland County Schools
# 47             1300120                             Atlanta Public Schools
# 48             2200540                            East Baton Rouge Parish
# 49             3411340                      NEWARK PUBLIC SCHOOL DISTRICT
# 50             3500060                         ALBUQUERQUE PUBLIC SCHOOLS
# 51             3701500               Winston Salem/Forsyth County Schools
# 52              638640                              Sweetwater Union High
# 53             1100030                District of Columbia Public Schools
# 54             4701590                                    Hamilton County
# 55             5307710                             Seattle Public Schools
# 56             3624750                     ROCHESTER CITY SCHOOL DISTRICT
# 57              406330                 Phoenix Union High School District
# 58             2400420                       Howard County Public Schools
# 59              102370                                      Mobile County
# 60             5103840                            VA BEACH CITY PBLC SCHS
# 61             4808940                                         AUSTIN ISD
# 62             2400060                 Anne Arundel County Public Schools
# 63             4818300                                        EL PASO ISD
# 64              901920                           HARTFORD SCHOOL DISTRICT
# 65             1301020                                             SCCPSS
# 66             5103130                        PRINCE WILLIAM CO PBLC SCHS
# 67              611820               East Side Union High School District
# 68             3904375                                    Cincinnati City
# 69              616230                               Grossmont Union High
# 70             4819650                                      FORT BEND ISD
# 71             3704620                        Union County Public Schools
# 72             06CC366                           Green Dot Public Schools
# 73             3701620                              Gaston County Schools
# 74             2929280                                     ST. LOUIS CITY
# 75             4833120                                      NORTHSIDE ISD
# 76             1201530                                              PASCO
# 77              101920                                   Jefferson County
# 78             4501440                                      Charleston 01
# 79             4022770                                      OKLAHOMA CITY
# 80             2400330                    Frederick County Public Schools
# 81             1304380                                    Richmond County
# 82              633840                            Sacramento City Unified
# 83              634410                              San Francisco Unified
# 84             5100840                          CHESTERFIELD CO PBLC SCHS
# 85             4502490                                           Horry 01
# 86             4816110                              CYPRESS-FAIRBANKS ISD
# 87             2200840                                   Jefferson Parish
# 88             1301230                                     Clayton County
# 89              408800                            Tucson Unified District
# 90             1302820                                       Henry County
# 91             3412690                    Paterson Public School District
# 92              612330                                  Elk Grove Unified
# 93              622500                                 Long Beach Unified
# 94             1303870                                    Muscogee County
# 95             4704530                          Williamson County Schools
# 96             1201260                                             MARION
# 97             1201920                                            VOLUSIA
# 98             4704020                                      Sumner County
# 99              803450            Douglas County School District No. Re 1
#
# SCH_APENR_IND LEA_STATE  Yes  Total Schools  pct_ap
# 0                    NY  230            347    0.66
# 1                    CA  103            105    0.98
# 2                    IL   92             97    0.95
# 3                    FL   73             77    0.95
# 4                    NV   43             46    0.93
# 5                    TN   23             40    0.57
# 6                    HI   37             39    0.95
# 7                    TX   38             38    1.00
# 8                    PA   33             37    0.89
# 9                    TX   34             35    0.97
# 10                   FL   34             35    0.97
# 11                   CA   21             30    0.70
# 12                   FL   29             29    1.00
# 13                   FL   26             28    0.93
# 14                   NC   22             27    0.81
# 15                   NC   26             26    1.00
# 16                   MD   25             25    1.00
# 17                   VA   25             25    1.00
# 18                   NC   23             24    0.96
# 19                   OH    0             24    0.00
# 20                   MD   22             23    0.96
# 21                   FL   20             22    0.91
# 22                   FL   20             22    0.91
# 23                   GA   21             21    1.00
# 24                   MD   21             21    1.00
# 25                   CO   19             21    0.90
# 26                   GA   20             20    1.00
# 27                   TN   15             19    0.79
# 28                   CA   17             19    0.89
# 29                   CO   15             19    0.79
# 30                   FL   17             18    0.94
# 31                   KY   17             18    0.94
# 32                   MD   10             18    0.56
# 33                   WI   15             18    0.83
# 34                   TN   14             17    0.82
# 35                   SC   14             17    0.82
# 36                   OH   16             17    0.94
# 37                   GA   16             16    1.00
# 38                   MI   11             16    0.69
# 39                   MA   15             16    0.94
# 40                   NV   12             16    0.75
# 41                   FL   14             16    0.88
# 42                   FL   15             16    0.94
# 43                   GA   16             16    1.00
# 44                   FL   13             15    0.87
# 45                   TX   15             15    1.00
# 46                   NC   11             14    0.79
# 47                   GA   14             14    1.00
# 48                   LA   11             13    0.85
# 49                   NJ   11             13    0.85
# 50                   NM   12             13    0.92
# 51                   NC   11             13    0.85
# 52                   CA   13             13    1.00
# 53                   DC   13             13    1.00
# 54                   TN    6             12    0.50
# 55                   WA   10             12    0.83
# 56                   NY    9             12    0.75
# 57                   AZ   11             12    0.92
# 58                   MD   12             12    1.00
# 59                   AL   11             12    0.92
# 60                   VA   12             12    1.00
# 61                   TX   12             12    1.00
# 62                   MD   12             12    1.00
# 63                   TX   11             12    0.92
# 64                   CT    6             11    0.55
# 65                   GA   10             11    0.91
# 66                   VA   11             11    1.00
# 67                   CA   11             11    1.00
# 68                   OH   11             11    1.00
# 69                   CA   11             11    1.00
# 70                   TX   11             11    1.00
# 71                   NC   10             11    0.91
# 72                   CA   11             11    1.00
# 73                   NC   10             11    0.91
# 74                   MO   10             11    0.91
# 75                   TX   11             11    1.00
# 76                   FL   11             11    1.00
# 77                   AL   10             10    1.00
# 78                   SC    9             10    0.90
# 79                   OK   10             10    1.00
# 80                   MD   10             10    1.00
# 81                   GA    9             10    0.90
# 82                   CA    9             10    0.90
# 83                   CA   10             10    1.00
# 84                   VA   10             10    1.00
# 85                   SC    8             10    0.80
# 86                   TX   10             10    1.00
# 87                   LA    8             10    0.80
# 88                   GA   10             10    1.00
# 89                   AZ    9             10    0.90
# 90                   GA   10             10    1.00
# 91                   NJ    9             10    0.90
# 92                   CA    9              9    1.00
# 93                   CA    8              9    0.89
# 94                   GA    8              9    0.89
# 95                   TN    8              9    0.89
# 96                   FL    8              9    0.89
# 97                   FL    9              9    1.00
# 98                   TN    7              9    0.78
# 99                   CO    9              9    1.00

# %%
"""Distribution of AP-Offering Percentages sorted by largest to smallest districts (top 100), so left-x-axis have the
largest districts, and right-x-axis have the smallest."""
plt.figure(figsize=(10,4))
ap_by_district.drop(['No'], axis = 1).sort_values('Total Schools', ascending = False).reset_index().drop(['index'], axis = 1).head(100)['pct_ap'].plot.bar()
plt.xticks([])
plt.title('AP-Offering Percentages of the Top 100 Districts')
# Out:
# Text(0.5,1,'AP-Offering Percentages of the Top 100 Districts')

# %%
ap_by_district.drop(['No'], axis = 1).sort_values(['Total Schools'], ascending = False).reset_index().drop(['index'], axis = 1).head(100).sort_values('pct_ap', ascending = False)
# Out:
# SCH_APENR_IND    LEAID                                           LEA_NAME  \
# 99              803450            Douglas County School District No. Re 1
# 68             3904375                                    Cincinnati City
# 80             2400330                    Frederick County Public Schools
# 26             1302550                                    Gwinnett County
# 77              101920                                   Jefferson County
# 76             1201530                                              PASCO
# 75             4833120                                      NORTHSIDE ISD
# 72             06CC366                           Green Dot Public Schools
# 70             4819650                                      FORT BEND ISD
# 69              616230                               Grossmont Union High
# 37             1302280                                      Fulton County
# 67              611820               East Side Union High School District
# 23             1301740                                      DeKalb County
# 66             5103130                        PRINCE WILLIAM CO PBLC SCHS
# 43             1301290                                        Cobb County
# 45             4819700                                     FORT WORTH ISD
# 62             2400060                 Anne Arundel County Public Schools
# 47             1300120                             Atlanta Public Schools
# 61             4808940                                         AUSTIN ISD
# 60             5103840                            VA BEACH CITY PBLC SCHS
# 52              638640                              Sweetwater Union High
# 53             1100030                District of Columbia Public Schools
# 24             2400120                    Baltimore County Public Schools
# 79             4022770                                      OKLAHOMA CITY
# 83              634410                              San Francisco Unified
# 15             3702970                      Charlotte-Mecklenburg Schools
# 97             1201920                                            VOLUSIA
# 7              4823640                                        HOUSTON ISD
# 92              612330                                  Elk Grove Unified
# 90             1302820                                       Henry County
# ..                 ...                                                ...
# 94             1303870                                    Muscogee County
# 28              619540                                          Kern High
# 93              622500                                 Long Beach Unified
# 95             4704530                          Williamson County Schools
# 41             1201080                                                LEE
# 44             1201590                                               POLK
# 48             2200540                            East Baton Rouge Parish
# 49             3411340                      NEWARK PUBLIC SCHOOL DISTRICT
# 51             3701500               Winston Salem/Forsyth County Schools
# 33             5509600                          Milwaukee School District
# 55             5307710                             Seattle Public Schools
# 34             4702220                                        Knox County
# 35             4502310                                      Greenville 01
# 14             3701920                            Guilford County Schools
# 85             4502490                                           Horry 01
# 87             2200840                                   Jefferson Parish
# 29              803360  School District No. 1 in the county of Denver ...
# 27             4703180                                    Davidson County
# 46             3700011                          Cumberland County Schools
# 98             4704020                                      Sumner County
# 56             3624750                     ROCHESTER CITY SCHOOL DISTRICT
# 40             3200480                      WASHOE COUNTY SCHOOL DISTRICT
# 11              634320                                  San Diego Unified
# 38             2612000                       Detroit City School District
# 0              3620580                       NEW YORK CITY PUBLIC SCHOOLS
# 5              4700148                              Shelby County Schools
# 32             2400090                      Baltimore City Public Schools
# 64              901920                           HARTFORD SCHOOL DISTRICT
# 54             4701590                                    Hamilton County
# 19             3904378             Cleveland Metropolitan School District
#
# SCH_APENR_IND LEA_STATE  Yes  Total Schools  pct_ap
# 99                   CO    9              9    1.00
# 68                   OH   11             11    1.00
# 80                   MD   10             10    1.00
# 26                   GA   20             20    1.00
# 77                   AL   10             10    1.00
# 76                   FL   11             11    1.00
# 75                   TX   11             11    1.00
# 72                   CA   11             11    1.00
# 70                   TX   11             11    1.00
# 69                   CA   11             11    1.00
# 37                   GA   16             16    1.00
# 67                   CA   11             11    1.00
# 23                   GA   21             21    1.00
# 66                   VA   11             11    1.00
# 43                   GA   16             16    1.00
# 45                   TX   15             15    1.00
# 62                   MD   12             12    1.00
# 47                   GA   14             14    1.00
# 61                   TX   12             12    1.00
# 60                   VA   12             12    1.00
# 52                   CA   13             13    1.00
# 53                   DC   13             13    1.00
# 24                   MD   21             21    1.00
# 79                   OK   10             10    1.00
# 83                   CA   10             10    1.00
# 15                   NC   26             26    1.00
# 97                   FL    9              9    1.00
# 7                    TX   38             38    1.00
# 92                   CA    9              9    1.00
# 90                   GA   10             10    1.00
# ..                  ...  ...            ...     ...
# 94                   GA    8              9    0.89
# 28                   CA   17             19    0.89
# 93                   CA    8              9    0.89
# 95                   TN    8              9    0.89
# 41                   FL   14             16    0.88
# 44                   FL   13             15    0.87
# 48                   LA   11             13    0.85
# 49                   NJ   11             13    0.85
# 51                   NC   11             13    0.85
# 33                   WI   15             18    0.83
# 55                   WA   10             12    0.83
# 34                   TN   14             17    0.82
# 35                   SC   14             17    0.82
# 14                   NC   22             27    0.81
# 85                   SC    8             10    0.80
# 87                   LA    8             10    0.80
# 29                   CO   15             19    0.79
# 27                   TN   15             19    0.79
# 46                   NC   11             14    0.79
# 98                   TN    7              9    0.78
# 56                   NY    9             12    0.75
# 40                   NV   12             16    0.75
# 11                   CA   21             30    0.70
# 38                   MI   11             16    0.69
# 0                    NY  230            347    0.66
# 5                    TN   23             40    0.57
# 32                   MD   10             18    0.56
# 64                   CT    6             11    0.55
# 54                   TN    6             12    0.50
# 19                   OH    0             24    0.00
#
# [100 rows x 6 columns]

# %% [markdown]
# # ScatterGeo

# %%
de_map = {'Yes':1, 'No':0}
dual_enroll_bin = hs.SCH_DUAL_IND.map(de_map)

# %%
# scl = [ [0,"rgb(5, 10, 172)"], [1,"rgb(0, 200, 100)"] ]


# data = [ dict(
#         type = 'scattergeo',
#         locationmode = 'USA-states',
#         lon = hs['LON1516'],
#         lat = hs['LAT1516'],
#         mode = 'markers',
#         marker = dict(
#             size = 5,
#             opacity = 0.8,
#             autocolorscale = False,
#             line = dict(
#                 width=1,
#                 color='rgba(255,255,255,1)'
#             ),
#             colorscale = scl,
#             cmin = 0,
#             color = dual_enroll_bin,
#             cmax = 1,
#         ))]

# layout = dict(
#         geo = dict(
#             scope='usa',
#             projection=dict( type='albers usa' ),
            
#         ),
#     )

# fig = dict( data=data, layout=layout )
# # fig = go.Figure(data = [data], layout = layout)
# iplot(fig, image = 'png', filename = '02_ScatterGeo_DE_1516', image_width = 3500, image_height=3250)

print("To see the scattergeo, uncomment code and change the size of the markers (to 3-5) -- Very cumbersome Graph")
# Out:
# To see the scattergeo, uncomment code and change the size of the markers (to 3-5) -- Very cumbersome Graph
