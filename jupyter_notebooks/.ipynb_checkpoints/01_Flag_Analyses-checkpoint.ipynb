# %% [markdown]
# # <u> NACEP </u>
# ## 2015-16 CRDC
# ## AP v. DE Flag Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import plotly.plotly as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode,iplot
init_notebook_mode(connected = True)

# %matplotlib inline
sns.set_style('whitegrid')
plt.rc('axes', titlesize = 14, titleweight = 'bold', labelweight = 'bold')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
hs = pd.read_csv('../filtered_data/04_filter_final.csv', dtype = {'LEAID':np.object})

# %%
hs.columns.values
# Out:
# array(['COMBOKEY', 'SCH_NAME', 'GSHI', 'GSLO', 'JJ', 'LAT1516', 'LEAID',
#        'LEA_NAME', 'LEA_STATE', 'LEA_STATE_NAME', 'LEVEL', 'LOCALE15',
#        'LON1516', 'NMCNTY15', 'SCHID', 'SCH_APENR_AM_F', 'SCH_APENR_AM_M',
#        'SCH_APENR_AS_F', 'SCH_APENR_AS_M', 'SCH_APENR_BL_F',
#        'SCH_APENR_BL_M', 'SCH_APENR_HI_F', 'SCH_APENR_HI_M',
#        'SCH_APENR_HP_F', 'SCH_APENR_HP_M', 'SCH_APENR_IDEA_F',
#        'SCH_APENR_IDEA_M', 'SCH_APENR_IND', 'SCH_APENR_LEP_F',
#        'SCH_APENR_LEP_M', 'SCH_APENR_TR_F', 'SCH_APENR_TR_M',
#        'SCH_APENR_WH_F', 'SCH_APENR_WH_M', 'SCH_DUALENR_AM_F',
#        'SCH_DUALENR_AM_M', 'SCH_DUALENR_AS_F', 'SCH_DUALENR_AS_M',
#        'SCH_DUALENR_BL_F', 'SCH_DUALENR_BL_M', 'SCH_DUALENR_HI_F',
#        'SCH_DUALENR_HI_M', 'SCH_DUALENR_HP_F', 'SCH_DUALENR_HP_M',
#        'SCH_DUALENR_IDEA_F', 'SCH_DUALENR_IDEA_M', 'SCH_DUALENR_LEP_F',
#        'SCH_DUALENR_LEP_M', 'SCH_DUALENR_TR_F', 'SCH_DUALENR_TR_M',
#        'SCH_DUALENR_WH_F', 'SCH_DUALENR_WH_M', 'SCH_DUAL_IND',
#        'SCH_ENR_AM_F', 'SCH_ENR_AM_M', 'SCH_ENR_AS_F', 'SCH_ENR_AS_M',
#        'SCH_ENR_BL_F', 'SCH_ENR_BL_M', 'SCH_ENR_HI_F', 'SCH_ENR_HI_M',
#        'SCH_ENR_HP_F', 'SCH_ENR_HP_M', 'SCH_ENR_IDEA_F', 'SCH_ENR_IDEA_M',
#        'SCH_ENR_LEP_F', 'SCH_ENR_LEP_M', 'SCH_ENR_TR_F', 'SCH_ENR_TR_M',
#        'SCH_ENR_WH_F', 'SCH_ENR_WH_M', 'SCH_GRADE_G01', 'SCH_GRADE_G02',
#        'SCH_GRADE_G03', 'SCH_GRADE_G04', 'SCH_GRADE_G05', 'SCH_GRADE_G06',
#        'SCH_GRADE_G07', 'SCH_GRADE_G08', 'SCH_GRADE_G09', 'SCH_GRADE_G10',
#        'SCH_GRADE_G11', 'SCH_GRADE_G12', 'SCH_GRADE_KG', 'SCH_GRADE_PS',
#        'SCH_GRADE_UG', 'SCH_IBENR_AM_F', 'SCH_IBENR_AM_M',
#        'SCH_IBENR_AS_F', 'SCH_IBENR_AS_M', 'SCH_IBENR_BL_F',
#        'SCH_IBENR_BL_M', 'SCH_IBENR_HI_F', 'SCH_IBENR_HI_M',
#        'SCH_IBENR_HP_F', 'SCH_IBENR_HP_M', 'SCH_IBENR_IDEA_F',
#        'SCH_IBENR_IDEA_M', 'SCH_IBENR_IND', 'SCH_IBENR_LEP_F',
#        'SCH_IBENR_LEP_M', 'SCH_IBENR_TR_F', 'SCH_IBENR_TR_M',
#        'SCH_IBENR_WH_F', 'SCH_IBENR_WH_M', 'SCH_STATUS_ALT',
#        'SCH_STATUS_CHARTER', 'SCH_STATUS_MAGNET', 'SCH_STATUS_SPED',
#        'SCH_TYPE', 'SCH_TYPE_TEXT', 'SCH_UGDETAIL_HS', 'STABR',
#        'Students_in_11_12', 'TITLEI', 'TOT_APENR_F', 'TOT_APENR_M',
#        'TOT_DUALENR_F', 'TOT_DUALENR_M', 'TOT_ENR_F', 'TOT_ENR_M',
#        'TOT_IBENR_F', 'TOT_IBENR_M', 'VIRTUAL'], dtype=object)

# %% [markdown]
# # National

# %% [markdown]
# ### -- Overall Breakdowns

# %% [markdown]
# <div class = 'alert alert-cell alert-info'>**All DE**</div>

# %%
de_breakdown = hs.groupby(['SCH_DUAL_IND'])['LEAID'].count()
print(de_breakdown)
print("")
de_pct = round(de_breakdown.iloc[1] / (de_breakdown.iloc[0] + de_breakdown.iloc[1]), 3)
print(str(de_pct) + " percent of schools in this dataset reported that they offered dual enrollment in 2013-2014.")
# Out:
# SCH_DUAL_IND
# No      5337
# Yes    13330
# Name: LEAID, dtype: int64
#
# 0.714 percent of schools in this dataset reported that they offered dual enrollment in 2013-2014.

# %% [markdown]
# <div class = 'alert alert-cell alert-info'>**All AP**</div>

# %%
ap_breakdown = hs.groupby(['SCH_APENR_IND'])['LEAID'].count()
print(ap_breakdown)
print("")
ap_pct = round(ap_breakdown.iloc[1] / (ap_breakdown.iloc[0] + ap_breakdown.iloc[1]), 3)
print(str(ap_pct) + " percent of schools in this dataset reported that they offered AP in 2013-2014.")
# Out:
# SCH_APENR_IND
# No      5911
# Yes    12756
# Name: LEAID, dtype: int64
#
# 0.683 percent of schools in this dataset reported that they offered AP in 2013-2014.

# %% [markdown]
# ## - By Size
# (Based on Total Enrollment of School)

# %% [markdown]
# <div class = 'alert alert-cell alert-danger'>**Create a Size-of-School Classifier**</div>

# %%
hs['total_enrollment'] = hs['TOT_ENR_M'] + hs['TOT_ENR_F']
from my_functions.extra_functions import hs_enrollment_averager
hs['hs_total_enrollment'] = hs_enrollment_averager(hs) # Calculating HS Students from the Total_Enrollments in Schools

# %%
from my_functions.extra_functions import school_sizer
hs['size_group'] = hs['hs_total_enrollment'].apply(lambda x: school_sizer(x))

# %%
sns.countplot(x = 'size_group', data = hs)
plt.title('Number of Schools in each Size Group')
plt.xticks([0,1,2,3], ['<100', '100-499', '500-1199', '>1200'])
plt.xlabel('')
# Out:
# Text(0.5,0,'')

# %% [markdown]
# <div class = 'alert alert-cell alert-info'>**DE**</div>

# %%
hs_by_size = hs.groupby(['size_group', 'SCH_DUAL_IND'])['LEAID'].count().unstack().reset_index()
hs_by_size['Total Schools'] = (hs_by_size['Yes'] + hs_by_size['No'])
hs_by_size['pct_de'] = round(hs_by_size['Yes'] / (hs_by_size['Yes'] + hs_by_size['No']), 2)
display(hs_by_size.drop(['No'], axis = 1))
# %store hs_by_size
# Out:
# SCH_DUAL_IND  size_group   Yes  Total Schools  pct_de
# 0                      1  1331           2358    0.56
# 1                      2  5225           7390    0.71
# 2                      3  3409           4543    0.75
# 3                      4  3365           4376    0.77
# Stored 'hs_by_size' (DataFrame)

# %% [markdown]
# <div class = 'alert alert-cell alert-warning'>**AP**</div>

# %%
ap_by_size = hs.groupby(['size_group', 'SCH_APENR_IND'])['LEAID'].count().unstack().reset_index()
ap_by_size['Total Schools'] = (ap_by_size['Yes'] + ap_by_size['No'])
ap_by_size['pct_ap'] = round(ap_by_size['Yes'] / (ap_by_size['Yes'] + ap_by_size['No']), 2)
display(ap_by_size.drop(['No'], axis = 1))
# %store ap_by_size
# Out:
# SCH_APENR_IND  size_group   Yes  Total Schools  pct_ap
# 0                       1   333           2358    0.14
# 1                       2  4100           7390    0.55
# 2                       3  4035           4543    0.89
# 3                       4  4288           4376    0.98
# Stored 'ap_by_size' (DataFrame)

# %% [markdown]
# <div class = 'alert alert-cell alert-danger'>**Visualizations**</div>

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize = (10,4))

plt.sca(ax1)
hs_by_size.plot.bar(x = 'size_group', y = 'pct_de', ax = ax1)
plt.xticks(rotation = 0)
plt.legend([])
plt.xlabel('')
plt.title('Percentage of Schools Offering DE\nBy Size ')
plt.yticks(np.arange(0,1.1,0.1))
plt.xticks([0,1,2,3], ['<100', '100-499', '500-1199', '>1200'])
plt.ylim([0,1])

plt.sca(ax2)
ap_by_size.plot.bar(x = 'size_group', y = 'pct_ap', ax=ax2)
plt.xticks(rotation = 0)
plt.legend([])
plt.xlabel('')
plt.title('Percentage of Schools Offering AP\nBy Size ')
plt.yticks(np.arange(0,1.1,0.1))
plt.xticks([0,1,2,3], ['<100', '100-499', '500-1199', '>1200'])
plt.ylim([0,1])
# Out:
# (0, 1)

# %% [markdown]
# ## - By Locale

# %% [markdown]
# <div class = 'alert alert-cell alert-danger'>**Creating a Locale Classifer**</div>

# %%
from my_functions.extra_functions import locale_map
hs['locale_group'] = hs['LOCALE15'].map(locale_map)

# %% [markdown]
# <div class = 'alert alert-cell alert-info'>**DE**</div>

# %%
de_by_locale = hs.groupby(['locale_group', 'SCH_DUAL_IND'])['LEA_STATE'].count().unstack('SCH_DUAL_IND').reset_index()
de_by_locale['Total Schools'] = (de_by_locale['Yes'] + de_by_locale['No'])
de_by_locale['pct_de'] = round(de_by_locale['Yes'] / (de_by_locale['Yes'] + de_by_locale['No']), 2)
display(de_by_locale.drop(['No'], axis = 1))
# %store de_by_locale
# Out:
# SCH_DUAL_IND locale_group   Yes  Total Schools  pct_de
# 0                    City  2301           4109    0.56
# 1                   Rural  5853           7438    0.79
# 2                Suburban  3126           4481    0.70
# 3                    Town  2050           2639    0.78
# Stored 'de_by_locale' (DataFrame)

# %% [markdown]
# <div class = 'alert alert-cell alert-warning'>**AP**</div>

# %%
ap_by_locale = hs.groupby(['locale_group', 'SCH_APENR_IND'])['LEA_STATE'].count().unstack().reset_index()
ap_by_locale['Total Schools'] = (ap_by_locale['Yes'] + ap_by_locale['No'])
ap_by_locale['pct_ap'] = round(ap_by_locale['Yes'] / (ap_by_locale['Yes'] + ap_by_locale['No']), 2)
display(ap_by_locale.drop(['No'], axis = 1))
# %store ap_by_locale
# Out:
# SCH_APENR_IND locale_group   Yes  Total Schools  pct_ap
# 0                     City  3152           4109    0.77
# 1                    Rural  3827           7438    0.51
# 2                 Suburban  3925           4481    0.88
# 3                     Town  1852           2639    0.70
# Stored 'ap_by_locale' (DataFrame)

# %% [markdown]
# <div class = 'alert alert-cell alert-danger'>**Visualizations**</div>

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize = (10,4))

plt.sca(ax1)
de_by_locale.plot.bar(x = 'locale_group', y = 'pct_de', ax=ax1)
plt.title('Percentage of Schools Offering DE\n by Locale')
plt.xticks(rotation = 0)
plt.legend([])
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')

plt.sca(ax2)
ap_by_locale.plot.bar(x = 'locale_group', y = 'pct_ap', ax=ax2)
plt.title('Percentage of Schools Offering AP\n by Locale')
plt.xticks(rotation = 0)
plt.legend([])
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')
# Out:
# Text(0.5,0,'')

# %% [markdown]
# ## - By Charter Status

# %%
"""How many charter schools exist in the set?"""
hs.SCH_STATUS_CHARTER.value_counts()
# Out:
# No     16876
# Yes     1791
# Name: SCH_STATUS_CHARTER, dtype: int64

# %% [markdown]
# <div class = 'alert alert-cell alert-info'>**DE**</div>

# %%
de_by_charter = hs.groupby(['SCH_STATUS_CHARTER', 'SCH_DUAL_IND'])['LEAID'].count().unstack().reset_index()
de_by_charter['SCH_STATUS_CHARTER'] = de_by_charter['SCH_STATUS_CHARTER'].map({'No':'Regular', 'Yes':'Charter'})
de_by_charter['Total Schools'] = (de_by_charter['No'] + de_by_charter['Yes'])
de_by_charter['pct_de'] = round(de_by_charter['Yes'] / (de_by_charter['No'] + de_by_charter['Yes']), 2)
de_by_charter.drop(['No'], axis = 1)
# Out:
# SCH_DUAL_IND SCH_STATUS_CHARTER    Yes  Total Schools  pct_de
# 0                       Regular  12542          16876    0.74
# 1                       Charter    788           1791    0.44

# %% [markdown]
# <div class = 'alert alert-cell alert-warning'>**AP**</div>

# %%
ap_by_charter = hs.groupby(['SCH_STATUS_CHARTER', 'SCH_APENR_IND'])['LEAID'].count().unstack().reset_index()
ap_by_charter['SCH_STATUS_CHARTER'] = ap_by_charter['SCH_STATUS_CHARTER'].map({'No':'Regular', 'Yes':'Charter'})
ap_by_charter['Total Schools'] = (ap_by_charter['No'] + ap_by_charter['Yes'])
ap_by_charter['pct_ap'] = round(ap_by_charter['Yes'] / (ap_by_charter['No'] + ap_by_charter['Yes']), 2)
ap_by_charter.drop(['No'], axis = 1)
# Out:
# SCH_APENR_IND SCH_STATUS_CHARTER    Yes  Total Schools  pct_ap
# 0                        Regular  11940          16876    0.71
# 1                        Charter    816           1791    0.46

# %% [markdown]
# <div class = 'alert alert-cell alert-danger'>**Visualizations**</div>

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize = (10,4))

plt.sca(ax1)
de_by_charter.plot.bar(x = 'SCH_STATUS_CHARTER', y = 'pct_de', ax=ax1)
plt.legend([])
plt.title('Percentage of Schools with DE\nBy Charter Status')
plt.xticks(rotation = 0)
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')

plt.sca(ax2)
ap_by_charter.plot.bar(x = 'SCH_STATUS_CHARTER', y = 'pct_ap', ax=ax2)
plt.legend([])
plt.title('Percentage of Schools with AP\nBy Charter Status')
plt.xticks(rotation = 0)
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')
# Out:
# Text(0.5,0,'')

# %% [markdown]
# # - By Title I Eligibility

# %% [markdown]
# <div class = 'alert alert-cell alert-danger'>**Filter out all schools with missing values**</div>

# %%
hs.TITLEI.value_counts()
# Out:
# Yes               11947
# No                 6083
# -9                  353
# Not Applicable      143
# Missing             141
# Name: TITLEI, dtype: int64

# %%
"""Remove the Misreported/Null Values"""
hs_by_titleI = hs.drop(hs[(hs.TITLEI == 'Missing') | (hs.TITLEI == 'Not Applicable') | (hs.TITLEI == '-9')].index, axis = 0)
hs_by_titleI.TITLEI.value_counts()
# Out:
# Yes    11947
# No      6083
# Name: TITLEI, dtype: int64

# %% [markdown]
# <div class = 'alert alert-cell alert-info'>**DE**</div>

# %%
de_by_titleI = hs_by_titleI.groupby(['TITLEI', 'SCH_DUAL_IND'])['LEAID'].count().unstack().reset_index()
de_by_titleI['TITLEI'] = de_by_titleI['TITLEI'].map({'Yes':'Eligible', 'No':'Not Eligible'})
de_by_titleI['Total Schools'] = (de_by_titleI['No'] + de_by_titleI['Yes'])
de_by_titleI['pct_de'] = round(de_by_titleI['Yes'] / (de_by_titleI['No'] + de_by_titleI['Yes']), 2)
de_by_titleI.drop(['No'], axis = 1)
# Out:
# SCH_DUAL_IND        TITLEI   Yes  Total Schools  pct_de
# 0             Not Eligible  4510           6083    0.74
# 1                 Eligible  8409          11947    0.70

# %% [markdown]
# <div class = 'alert alert-cell alert-warning'>**AP**</div>

# %%
ap_by_titleI = hs_by_titleI.groupby(['TITLEI', 'SCH_APENR_IND'])['LEAID'].count().unstack().reset_index()
ap_by_titleI['TITLEI'] = ap_by_titleI['TITLEI'].map({'Yes':'Eligible', 'No':'Not Eligible'})
ap_by_titleI['Total Schools'] = (ap_by_titleI['No'] + ap_by_titleI['Yes'])
ap_by_titleI['pct_ap'] = round(ap_by_titleI['Yes'] / (ap_by_titleI['No'] + ap_by_titleI['Yes']), 2)
ap_by_titleI.drop(['No'], axis = 1)
# Out:
# SCH_APENR_IND        TITLEI   Yes  Total Schools  pct_ap
# 0              Not Eligible  4578           6083    0.75
# 1                  Eligible  7876          11947    0.66

# %% [markdown]
# <div class = 'alert alert-cell alert-danger'>**Visualizations**</div>

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (10,4))

plt.sca(ax1)
de_by_titleI.plot.bar(x = 'TITLEI', y = 'pct_de', ax=ax1)
plt.legend([])
plt.title('Percentage of Schools with DE\nBy Title I Eligibility')
plt.xticks(rotation = 0)
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')

plt.sca(ax2)
ap_by_titleI.plot.bar(x = 'TITLEI', y = 'pct_ap', ax=ax2)
plt.legend([])
plt.title('Percentage of Schools with AP\nBy Title I Eligibility')
plt.xticks(rotation = 0)
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')
# Out:
# Text(0.5,0,'')

# %% [markdown]
# # - By Ethnicity Quintiles

# %% [markdown]
# <div class = 'alert alert-cell alert-danger'>**Calculate the percent ethnicity of all schools in the set and group schools into quintiles**</div>

# %%
hs['pct_eth'] = (hs['total_enrollment'] - hs['SCH_ENR_WH_F'] - hs['SCH_ENR_WH_M']) / hs['total_enrollment']
from my_functions.extra_functions import eth_grouper
hs['eth_quintile'] = hs['pct_eth'].apply(lambda pct: eth_grouper(pct))

# %%
"""What does the distribution of the schools in the dataset look based on ethncitiy?"""
hs.pct_eth.plot.hist(bins=100, xlim = [0,1], edgecolor = 'k')
plt.title('Distribution of Schools by Ethnicity Percentages')
plt.xlabel('Ethnicity Percentage')
# plt.savefig(fname = './Visualizations/By_ethnicity_dist_200.png', dpi = 200)
# Out:
# Text(0.5,0,'Ethnicity Percentage')

# %% [markdown]
# <div class = 'alert alert-cell alert-info'>**DE**</div>

# %%
hs_by_eth_quin = hs.groupby(['eth_quintile', 'SCH_DUAL_IND'])['LEAID'].count().unstack().reset_index()
hs_by_eth_quin['Total Schools'] = (hs_by_eth_quin['No'] + hs_by_eth_quin['Yes'])
hs_by_eth_quin['pct_de'] = round(hs_by_eth_quin['Yes'] / (hs_by_eth_quin['No'] + hs_by_eth_quin['Yes']), 2)
display(hs_by_eth_quin.drop(['No'], axis = 1))
# %store hs_by_eth_quin
# Out:
# SCH_DUAL_IND  eth_quintile   Yes  Total Schools  pct_de
# 0                        1  5677           7122    0.80
# 1                        2  2684           3502    0.77
# 2                        3  1755           2414    0.73
# 3                        4  1193           1824    0.65
# 4                        5  2021           3805    0.53
# Stored 'hs_by_eth_quin' (DataFrame)

# %% [markdown]
# <div class = 'alert alert-cell alert-warning'>**AP**</div>

# %%
ap_by_eth_quin = hs.groupby(['eth_quintile', 'SCH_APENR_IND'])['LEAID'].count().unstack().reset_index()
ap_by_eth_quin['Total Schools'] = (ap_by_eth_quin['No'] + ap_by_eth_quin['Yes'])
ap_by_eth_quin['pct_ap'] = round(ap_by_eth_quin['Yes'] / (ap_by_eth_quin['No'] + ap_by_eth_quin['Yes']), 2)
display(ap_by_eth_quin.drop(['No'], axis = 1))
# %store ap_by_eth_quin
# Out:
# SCH_APENR_IND  eth_quintile   Yes  Total Schools  pct_ap
# 0                         1  4385           7122    0.62
# 1                         2  2493           3502    0.71
# 2                         3  1828           2414    0.76
# 3                         4  1367           1824    0.75
# 4                         5  2683           3805    0.71
# Stored 'ap_by_eth_quin' (DataFrame)

# %% [markdown]
# <div class = 'alert alert-cell alert-danger'>**Visualization**</div>

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (10,4))
plt.sca(ax1)
ap_by_eth_quin.plot.bar(x = 'eth_quintile', y = 'pct_ap', ax = ax1)
plt.legend([])
plt.title('Percentage of Schools with AP\nBy Ethnicity Percentage Quintiles')
plt.xticks(rotation = 0)
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xticks([0,1,2,3,4], ['0-20%', '21-40%', '41-60%', '61-80%', '81-100%'])
plt.xlabel('')

plt.sca(ax2)
hs_by_eth_quin.plot.bar(x = 'eth_quintile', y = 'pct_de', ax = ax2)
plt.legend([])
plt.title('Percentage of Schools with DE\nBy Ethnicity Percentage Quintiles')
plt.xticks(rotation = 0)
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xticks([0,1,2,3,4], ['0-20%', '21-40%', '41-60%', '61-80%', '81-100%'])
plt.xlabel('')
# Out:
# Text(0.5,0,'')

# %% [markdown]
# <div class = 'alert alert-cell alert-info'>**Ethnicity Exploration**</div>

# %%
"""States with the highest number of 98%+ non-white schools (top 10)"""
hs[hs.pct_eth >= 0.98].groupby('LEA_STATE')['LEAID'].count().sort_values(ascending = False).head(10)
# Out:
# LEA_STATE
# NY    224
# CA    204
# TX    170
# IL     80
# AK     79
# NJ     53
# GA     49
# PA     44
# MS     42
# MI     40
# Name: LEAID, dtype: int64

# %%
"""Very high percentage non-minority schools by Locale"""
eth_group1_locales = hs[hs.eth_quintile == 1].groupby('locale_group')['LEAID'].count().reset_index()
eth_group1_locales['pct'] = round(eth_group1_locales['LEAID'] / eth_group1_locales['LEAID'].sum() * 100, 1)
eth_group1_locales = eth_group1_locales.set_index('locale_group')
eth_group1_locales
# Out:
#               LEAID   pct
# locale_group
# City            168   2.4
# Rural          4452  62.5
# Suburban       1223  17.2
# Town           1279  18.0

# %%
with plt.rc_context({'lines.linewidth': 5, 'font.weight':'bold', 'font.size':11}):
    eth_group1_locales.plot.pie(y='LEAID',autopct='%1.1f%%', 
                            startangle = 55, shadow = True, explode = [.05 for i in range(4)],
                            colormap='Pastel2', figsize = (5,5))
    plt.title('Schools by AP/DE Offering Status')
    plt.legend([])
    plt.ylabel('')
    plt.xticks(fontdict={'fontweight':'bold'})
    plt.axis('equal')

# %% [markdown]
# # - By Vocational Status

# %% [markdown]
# <div class='alert alert-cell alert-info'><b>DE</b></div>

# %%
hs_by_voc = hs.groupby(['SCH_TYPE', 'SCH_DUAL_IND'])['LEAID'].count().unstack().reset_index()
hs_by_voc['Total Schools'] = (hs_by_voc['No'] + hs_by_voc['Yes'])
hs_by_voc['pct_de'] = round(hs_by_voc['Yes'] / (hs_by_voc['No'] + hs_by_voc['Yes']), 2)

hs_by_voc['SCH_TYPE'] = hs_by_voc['SCH_TYPE'].astype(str)
hs_by_voc.at[0,'SCH_TYPE'] = 'Regular'
hs_by_voc.at[1,'SCH_TYPE'] = 'Vocational'
hs_by_voc = hs_by_voc.set_index('SCH_TYPE')

display(hs_by_voc.drop(['No'], axis = 1))
# Out:
# SCH_DUAL_IND    Yes  Total Schools  pct_de
# SCH_TYPE
# Regular       13124          18308    0.72
# Vocational      206            359    0.57

# %% [markdown]
# <div class='alert alert-cell alert-warning'><b>AP</b></div>

# %%
ap_by_voc = hs.groupby(['SCH_TYPE', 'SCH_APENR_IND'])['LEAID'].count().unstack().reset_index()
ap_by_voc['Total Schools'] = (ap_by_voc['No'] + ap_by_voc['Yes'])
ap_by_voc['pct_ap'] = round(ap_by_voc['Yes'] / (ap_by_voc['No'] + ap_by_voc['Yes']), 2)

ap_by_voc['SCH_TYPE'] = ap_by_voc['SCH_TYPE'].astype(str)
ap_by_voc.at[0,'SCH_TYPE'] = 'Regular'
ap_by_voc.at[1,'SCH_TYPE'] = 'Vocational'
ap_by_voc = ap_by_voc.set_index('SCH_TYPE')

display(ap_by_voc.drop(['No'], axis = 1))
# Out:
# SCH_APENR_IND    Yes  Total Schools  pct_ap
# SCH_TYPE
# Regular        12639          18308    0.69
# Vocational       117            359    0.33

# %% [markdown]
# <div class = 'alert alert-cell alert-danger'>**Visualizations**</div>

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize = (10,4))
plt.sca(ax1)
hs_by_voc.plot.bar(y = 'pct_de', ax = ax1)
plt.legend([])
plt.title('Percentage of Schools with DE\nBy Vocational Status')
plt.xticks(rotation = 0)
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')

plt.sca(ax2)
ap_by_voc.plot.bar(y = 'pct_ap', ax = ax2)
plt.legend([])
plt.title('Percentage of Schools with AP\nBy Vocational Status')
plt.xticks(rotation = 0)
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')
# Out:
# Text(0.5,0,'')

# %% [markdown]
# # - By (Largest) Districts
# How well do the largest districts (chosen by number of schools in the district) in offering DE/AP?

# %% [markdown]
# <div class = 'alert alert-cell alert-info'>**DE**</div>

# %%
hs_by_district = hs.groupby(['LEAID', 'LEA_NAME', 'LEA_STATE', 'SCH_DUAL_IND'])['LEAID'].count().unstack().reset_index()
hs_by_district = hs_by_district.fillna(0)
hs_by_district[['No', 'Yes']] = hs_by_district[['No', 'Yes']].astype(int)

hs_by_district['Total Schools'] = (hs_by_district['No'] + hs_by_district['Yes'])
hs_by_district['pct_de'] = round(hs_by_district['Yes'] / (hs_by_district['No'] + hs_by_district['Yes']), 2)

# %%
"""Top 100 Districts (by number of schools in district) and their DE-Offering Percentages"""
with pd.option_context('display.max_rows', 100):
    display(hs_by_district.drop(['No'], axis = 1).sort_values('Total Schools', ascending = False).reset_index().drop(['index'], axis = 1).head(100))
# Out:
# SCH_DUAL_IND    LEAID                                           LEA_NAME  \
# 0             3620580                       NEW YORK CITY PUBLIC SCHOOLS
# 1              622710                                Los Angeles Unified
# 2             1709930                             City of Chicago SD 299
# 3             1200390                                               DADE
# 4             1500030                     Hawaii Department of Education
# 5             3200060                       CLARK COUNTY SCHOOL DISTRICT
# 6             4218990                               Philadelphia City SD
# 7             1200180                                            BROWARD
# 8             4823640                                        HOUSTON ISD
# 9             4700148                              Shelby County Schools
# 10             634320                                  San Diego Unified
# 11            2400090                      Baltimore City Public Schools
# 12            4816230                                         DALLAS ISD
# 13            1200870                                       HILLSBOROUGH
# 14             803360  School District No. 1 in the county of Denver ...
# 15            3702970                      Charlotte-Mecklenburg Schools
# 16            1201500                                         PALM BEACH
# 17            3701920                            Guilford County Schools
# 18             804800           Jefferson County School District No. R-1
# 19            3704720                                Wake County Schools
# 20            3904378             Cleveland Metropolitan School District
# 21            2400510              Prince George's County Public Schools
# 22            5509600                          Milwaukee School District
# 23            5101260                               FAIRFAX CO PBLC SCHS
# 24            1200480                                              DUVAL
# 25            2400480                   Montgomery County Public Schools
# 26            2400120                    Baltimore County Public Schools
# 27            1201440                                             ORANGE
# 28             200001                    Lower Kuskokwim School District
# 29            2102990                                   Jefferson County
# 30            2502790                                             Boston
# 31            1301740                                      DeKalb County
# 32            1201590                                               POLK
# 33            4701590                                    Hamilton County
# 34            1302550                                    Gwinnett County
# 35            3904380                      Columbus City School District
# 36             619540                                          Kern High
# 37            4502310                                      Greenville 01
# 38            3200480                      WASHOE COUNTY SCHOOL DISTRICT
# 39            4703180                                    Davidson County
# 40             200390            Kenai Peninsula Borough School District
# 41            2612000                       Detroit City School District
# 42            1201560                                           PINELLAS
# 43             901920                           HARTFORD SCHOOL DISTRICT
# 44            1201080                                                LEE
# 45            1300120                             Atlanta Public Schools
# 46            4819700                                     FORT WORTH ISD
# 47            3701500               Winston Salem/Forsyth County Schools
# 48            1200150                                            BREVARD
# 49             900002           Connecticut Technical High School System
# 50            1301290                                        Cobb County
# 51            1302280                                      Fulton County
# 52            2200540                            East Baton Rouge Parish
# 53            5102250                               LOUDOUN CO PBLC SCHS
# 54            1100030                District of Columbia Public Schools
# 55            3605850                       BUFFALO CITY SCHOOL DISTRICT
# 56            4501440                                      Charleston 01
# 57            4702220                                        Knox County
# 58            2929280                                     ST. LOUIS CITY
# 59             200020                      Bering Strait School District
# 60            1201530                                              PASCO
# 61             200180                          Anchorage School District
# 62            3411340                      NEWARK PUBLIC SCHOOL DISTRICT
# 63            2200840                                   Jefferson Parish
# 64            3500060                         ALBUQUERQUE PUBLIC SCHOOLS
# 65            3700011                          Cumberland County Schools
# 66            3904375                                    Cincinnati City
# 67             638640                              Sweetwater Union High
# 68            3624750                     ROCHESTER CITY SCHOOL DISTRICT
# 69             406330                 Phoenix Union High School District
# 70             200510          Matanuska-Susitna Borough School District
# 71            1304380                                    Richmond County
# 72            4502490                                           Horry 01
# 73            2400060                 Anne Arundel County Public Schools
# 74             102370                                      Mobile County
# 75            3701260                              Durham Public Schools
# 76             101920                                   Jefferson County
# 77            4818300                                        EL PASO ISD
# 78             200625           Northwest Arctic Borough School District
# 79            2400420                       Howard County Public Schools
# 80            5103840                            VA BEACH CITY PBLC SCHS
# 81             800020                     State Charter School Institute
# 82            5307710                             Seattle Public Schools
# 83            4808940                                         AUSTIN ISD
# 84             200485         Lake and Peninsula Borough School District
# 85            1201470                                            OSCEOLA
# 86            2201290                                     Rapides Parish
# 87            4819650                                      FORT BEND ISD
# 88             616230                               Grossmont Union High
# 89            1301230                                     Clayton County
# 90            1301020                                             SCCPSS
# 91            2200330                                   Calcasieu Parish
# 92            4833120                                      NORTHSIDE ISD
# 93             803450            Douglas County School District No. Re 1
# 94            3701620                              Gaston County Schools
# 95            5103130                        PRINCE WILLIAM CO PBLC SCHS
# 96            06CC366                           Green Dot Public Schools
# 97            4704020                                      Sumner County
# 98             611820               East Side Union High School District
# 99            3704620                        Union County Public Schools
#
# SCH_DUAL_IND LEA_STATE  Yes  Total Schools  pct_de
# 0                   NY  124            460    0.27
# 1                   CA   66            114    0.58
# 2                   IL   79            112    0.71
# 3                   FL   66             81    0.81
# 4                   HI   57             63    0.90
# 5                   NV   11             54    0.20
# 6                   PA    0             49    0.00
# 7                   FL   38             46    0.83
# 8                   TX   30             45    0.67
# 9                   TN   24             42    0.57
# 10                  CA    8             39    0.21
# 11                  MD    3             37    0.08
# 12                  TX   26             35    0.74
# 13                  FL   20             31    0.65
# 14                  CO   20             31    0.65
# 15                  NC   26             30    0.87
# 16                  FL   26             30    0.87
# 17                  NC   26             29    0.90
# 18                  CO   28             28    1.00
# 19                  NC   12             27    0.44
# 20                  OH    0             27    0.00
# 21                  MD   23             26    0.88
# 22                  WI   18             26    0.69
# 23                  VA   16             25    0.64
# 24                  FL   23             25    0.92
# 25                  MD   25             25    1.00
# 26                  MD   24             24    1.00
# 27                  FL   22             24    0.92
# 28                  AK   20             23    0.87
# 29                  KY   13             22    0.59
# 30                  MA    0             22    0.00
# 31                  GA   16             22    0.73
# 32                  FL   19             21    0.90
# 33                  TN   16             21    0.76
# 34                  GA   18             20    0.90
# 35                  OH   19             20    0.95
# 36                  CA    0             19    0.00
# 37                  SC   15             18    0.83
# 38                  NV    9             18    0.50
# 39                  TN    4             18    0.22
# 40                  AK    9             18    0.50
# 41                  MI    1             18    0.06
# 42                  FL   17             18    0.94
# 43                  CT    5             17    0.29
# 44                  FL   15             17    0.88
# 45                  GA   11             17    0.65
# 46                  TX   17             17    1.00
# 47                  NC    0             16    0.00
# 48                  FL   16             16    1.00
# 49                  CT   15             16    0.94
# 50                  GA   16             16    1.00
# 51                  GA   16             16    1.00
# 52                  LA    3             15    0.20
# 53                  VA   15             15    1.00
# 54                  DC    1             15    0.07
# 55                  NY    7             15    0.47
# 56                  SC   13             15    0.87
# 57                  TN   14             15    0.93
# 58                  MO   12             14    0.86
# 59                  AK    4             14    0.29
# 60                  FL   14             14    1.00
# 61                  AK    9             14    0.64
# 62                  NJ   10             14    0.71
# 63                  LA   12             14    0.86
# 64                  NM    6             14    0.43
# 65                  NC   14             14    1.00
# 66                  OH   12             14    0.86
# 67                  CA   11             13    0.85
# 68                  NY    5             13    0.38
# 69                  AZ   12             13    0.92
# 70                  AK    6             13    0.46
# 71                  GA    9             13    0.69
# 72                  SC   12             13    0.92
# 73                  MD   13             13    1.00
# 74                  AL   12             12    1.00
# 75                  NC    5             12    0.42
# 76                  AL   10             12    0.83
# 77                  TX   12             12    1.00
# 78                  AK    6             12    0.50
# 79                  MD   12             12    1.00
# 80                  VA   11             12    0.92
# 81                  CO    6             12    0.50
# 82                  WA    6             12    0.50
# 83                  TX    8             12    0.67
# 84                  AK    0             11    0.00
# 85                  FL   10             11    0.91
# 86                  LA    8             11    0.73
# 87                  TX   11             11    1.00
# 88                  CA    1             11    0.09
# 89                  GA   11             11    1.00
# 90                  GA    7             11    0.64
# 91                  LA   11             11    1.00
# 92                  TX   11             11    1.00
# 93                  CO   11             11    1.00
# 94                  NC    0             11    0.00
# 95                  VA   11             11    1.00
# 96                  CA    0             11    0.00
# 97                  TN   10             11    0.91
# 98                  CA    2             11    0.18
# 99                  NC   10             11    0.91

# %%
"""Top 25 Districts at Offering DE"""
hs_by_district.drop(['No'], axis = 1).sort_values(['Total Schools'], ascending = False).reset_index(drop=True).head(100).sort_values('pct_de', ascending = False).reset_index(drop=True).head(25)
# Out:
# SCH_DUAL_IND    LEAID                                  LEA_NAME LEA_STATE  \
# 0             1301290                               Cobb County        GA
# 1             2400120           Baltimore County Public Schools        MD
# 2             1201530                                     PASCO        FL
# 3              804800  Jefferson County School District No. R-1        CO
# 4             3700011                 Cumberland County Schools        NC
# 5             2400480          Montgomery County Public Schools        MD
# 6             2400060        Anne Arundel County Public Schools        MD
# 7              102370                             Mobile County        AL
# 8             4818300                               EL PASO ISD        TX
# 9             1302280                             Fulton County        GA
# 10            2400420              Howard County Public Schools        MD
# 11            1200150                                   BREVARD        FL
# 12            4819650                             FORT BEND ISD        TX
# 13            1301230                            Clayton County        GA
# 14            2200330                          Calcasieu Parish        LA
# 15            4833120                             NORTHSIDE ISD        TX
# 16             803450   Douglas County School District No. Re 1        CO
# 17            5103130               PRINCE WILLIAM CO PBLC SCHS        VA
# 18            4819700                            FORT WORTH ISD        TX
# 19            5102250                      LOUDOUN CO PBLC SCHS        VA
# 20            3904380             Columbus City School District        OH
# 21             900002  Connecticut Technical High School System        CT
# 22            1201560                                  PINELLAS        FL
# 23            4702220                               Knox County        TN
# 24            1200480                                     DUVAL        FL
#
# SCH_DUAL_IND  Yes  Total Schools  pct_de
# 0              16             16    1.00
# 1              24             24    1.00
# 2              14             14    1.00
# 3              28             28    1.00
# 4              14             14    1.00
# 5              25             25    1.00
# 6              13             13    1.00
# 7              12             12    1.00
# 8              12             12    1.00
# 9              16             16    1.00
# 10             12             12    1.00
# 11             16             16    1.00
# 12             11             11    1.00
# 13             11             11    1.00
# 14             11             11    1.00
# 15             11             11    1.00
# 16             11             11    1.00
# 17             11             11    1.00
# 18             17             17    1.00
# 19             15             15    1.00
# 20             19             20    0.95
# 21             15             16    0.94
# 22             17             18    0.94
# 23             14             15    0.93
# 24             23             25    0.92

# %%
"""Bottom 25 Districts at Offering DE"""
hs_by_district.drop(['No'], axis = 1).sort_values(['Total Schools'], ascending = False).reset_index(drop=True).head(100).sort_values('pct_de').reset_index(drop=True).head(25)
# Out:
# SCH_DUAL_IND    LEAID                                    LEA_NAME LEA_STATE  \
# 0             06CC366                    Green Dot Public Schools        CA
# 1             3904378      Cleveland Metropolitan School District        OH
# 2             2502790                                      Boston        MA
# 3              619540                                   Kern High        CA
# 4             4218990                        Philadelphia City SD        PA
# 5              200485  Lake and Peninsula Borough School District        AK
# 6             3701620                       Gaston County Schools        NC
# 7             3701500        Winston Salem/Forsyth County Schools        NC
# 8             2612000                Detroit City School District        MI
# 9             1100030         District of Columbia Public Schools        DC
# 10            2400090               Baltimore City Public Schools        MD
# 11             616230                        Grossmont Union High        CA
# 12             611820        East Side Union High School District        CA
# 13            2200540                     East Baton Rouge Parish        LA
# 14            3200060                CLARK COUNTY SCHOOL DISTRICT        NV
# 15             634320                           San Diego Unified        CA
# 16            4703180                             Davidson County        TN
# 17            3620580                NEW YORK CITY PUBLIC SCHOOLS        NY
# 18             901920                    HARTFORD SCHOOL DISTRICT        CT
# 19             200020               Bering Strait School District        AK
# 20            3624750              ROCHESTER CITY SCHOOL DISTRICT        NY
# 21            3701260                       Durham Public Schools        NC
# 22            3500060                  ALBUQUERQUE PUBLIC SCHOOLS        NM
# 23            3704720                         Wake County Schools        NC
# 24             200510   Matanuska-Susitna Borough School District        AK
#
# SCH_DUAL_IND  Yes  Total Schools  pct_de
# 0               0             11    0.00
# 1               0             27    0.00
# 2               0             22    0.00
# 3               0             19    0.00
# 4               0             49    0.00
# 5               0             11    0.00
# 6               0             11    0.00
# 7               0             16    0.00
# 8               1             18    0.06
# 9               1             15    0.07
# 10              3             37    0.08
# 11              1             11    0.09
# 12              2             11    0.18
# 13              3             15    0.20
# 14             11             54    0.20
# 15              8             39    0.21
# 16              4             18    0.22
# 17            124            460    0.27
# 18              5             17    0.29
# 19              4             14    0.29
# 20              5             13    0.38
# 21              5             12    0.42
# 22              6             14    0.43
# 23             12             27    0.44
# 24              6             13    0.46

# %% [markdown]
# <div class = 'alert alert-cell alert-warning'>**AP**</div>

# %%
ap_by_district = hs.groupby(['LEAID', 'LEA_NAME', 'LEA_STATE', 'SCH_APENR_IND'])['LEAID'].count().unstack().reset_index()
ap_by_district = ap_by_district.fillna(0)
ap_by_district[['No', 'Yes']] = ap_by_district[['No', 'Yes']].astype(int)

ap_by_district['Total Schools'] = (ap_by_district['No'] + ap_by_district['Yes'])
ap_by_district['pct_ap'] = round(ap_by_district['Yes'] / (ap_by_district['No'] + ap_by_district['Yes']), 2)

# %%
"""Top 100 Districts (by number of schools in district) and their AP-Offering Percentages"""
with pd.option_context('display.max_rows', 100):
    display(ap_by_district.drop(['No'], axis = 1).sort_values('Total Schools', ascending = False).reset_index().drop(['index'], axis = 1).head(100))
# Out:
# SCH_APENR_IND    LEAID                                           LEA_NAME  \
# 0              3620580                       NEW YORK CITY PUBLIC SCHOOLS
# 1               622710                                Los Angeles Unified
# 2              1709930                             City of Chicago SD 299
# 3              1200390                                               DADE
# 4              1500030                     Hawaii Department of Education
# 5              3200060                       CLARK COUNTY SCHOOL DISTRICT
# 6              4218990                               Philadelphia City SD
# 7              1200180                                            BROWARD
# 8              4823640                                        HOUSTON ISD
# 9              4700148                              Shelby County Schools
# 10              634320                                  San Diego Unified
# 11             2400090                      Baltimore City Public Schools
# 12             4816230                                         DALLAS ISD
# 13             1200870                                       HILLSBOROUGH
# 14              803360  School District No. 1 in the county of Denver ...
# 15             3702970                      Charlotte-Mecklenburg Schools
# 16             1201500                                         PALM BEACH
# 17             3701920                            Guilford County Schools
# 18              804800           Jefferson County School District No. R-1
# 19             3704720                                Wake County Schools
# 20             3904378             Cleveland Metropolitan School District
# 21             2400510              Prince George's County Public Schools
# 22             5509600                          Milwaukee School District
# 23             5101260                               FAIRFAX CO PBLC SCHS
# 24             1200480                                              DUVAL
# 25             2400480                   Montgomery County Public Schools
# 26             2400120                    Baltimore County Public Schools
# 27             1201440                                             ORANGE
# 28              200001                    Lower Kuskokwim School District
# 29             2102990                                   Jefferson County
# 30             2502790                                             Boston
# 31             1301740                                      DeKalb County
# 32             1201590                                               POLK
# 33             4701590                                    Hamilton County
# 34             1302550                                    Gwinnett County
# 35             3904380                      Columbus City School District
# 36              619540                                          Kern High
# 37             4502310                                      Greenville 01
# 38             3200480                      WASHOE COUNTY SCHOOL DISTRICT
# 39             4703180                                    Davidson County
# 40              200390            Kenai Peninsula Borough School District
# 41             2612000                       Detroit City School District
# 42             1201560                                           PINELLAS
# 43              901920                           HARTFORD SCHOOL DISTRICT
# 44             1201080                                                LEE
# 45             1300120                             Atlanta Public Schools
# 46             4819700                                     FORT WORTH ISD
# 47             3701500               Winston Salem/Forsyth County Schools
# 48             1200150                                            BREVARD
# 49              900002           Connecticut Technical High School System
# 50             1301290                                        Cobb County
# 51             1302280                                      Fulton County
# 52             2200540                            East Baton Rouge Parish
# 53             5102250                               LOUDOUN CO PBLC SCHS
# 54             1100030                District of Columbia Public Schools
# 55             3605850                       BUFFALO CITY SCHOOL DISTRICT
# 56             4501440                                      Charleston 01
# 57             4702220                                        Knox County
# 58             2929280                                     ST. LOUIS CITY
# 59              200020                      Bering Strait School District
# 60             1201530                                              PASCO
# 61              200180                          Anchorage School District
# 62             3411340                      NEWARK PUBLIC SCHOOL DISTRICT
# 63             2200840                                   Jefferson Parish
# 64             3500060                         ALBUQUERQUE PUBLIC SCHOOLS
# 65             3700011                          Cumberland County Schools
# 66             3904375                                    Cincinnati City
# 67              638640                              Sweetwater Union High
# 68             3624750                     ROCHESTER CITY SCHOOL DISTRICT
# 69              406330                 Phoenix Union High School District
# 70              200510          Matanuska-Susitna Borough School District
# 71             1304380                                    Richmond County
# 72             4502490                                           Horry 01
# 73             2400060                 Anne Arundel County Public Schools
# 74              102370                                      Mobile County
# 75             3701260                              Durham Public Schools
# 76              101920                                   Jefferson County
# 77             4818300                                        EL PASO ISD
# 78              200625           Northwest Arctic Borough School District
# 79             2400420                       Howard County Public Schools
# 80             5103840                            VA BEACH CITY PBLC SCHS
# 81              800020                     State Charter School Institute
# 82             5307710                             Seattle Public Schools
# 83             4808940                                         AUSTIN ISD
# 84              200485         Lake and Peninsula Borough School District
# 85             1201470                                            OSCEOLA
# 86             2201290                                     Rapides Parish
# 87             4819650                                      FORT BEND ISD
# 88              616230                               Grossmont Union High
# 89             1301230                                     Clayton County
# 90             1301020                                             SCCPSS
# 91             2200330                                   Calcasieu Parish
# 92             4833120                                      NORTHSIDE ISD
# 93              803450            Douglas County School District No. Re 1
# 94             3701620                              Gaston County Schools
# 95             5103130                        PRINCE WILLIAM CO PBLC SCHS
# 96             06CC366                           Green Dot Public Schools
# 97             4704020                                      Sumner County
# 98              611820               East Side Union High School District
# 99             3704620                        Union County Public Schools
#
# SCH_APENR_IND LEA_STATE  Yes  Total Schools  pct_ap
# 0                    NY  314            460    0.68
# 1                    CA  112            114    0.98
# 2                    IL  104            112    0.93
# 3                    FL   78             81    0.96
# 4                    HI   42             63    0.67
# 5                    NV   48             54    0.89
# 6                    PA   41             49    0.84
# 7                    FL   42             46    0.91
# 8                    TX   44             45    0.98
# 9                    TN   26             42    0.62
# 10                   CA   25             39    0.64
# 11                   MD   23             37    0.62
# 12                   TX   34             35    0.97
# 13                   FL   29             31    0.94
# 14                   CO   25             31    0.81
# 15                   NC   30             30    1.00
# 16                   FL   28             30    0.93
# 17                   NC   23             29    0.79
# 18                   CO   21             28    0.75
# 19                   NC   26             27    0.96
# 20                   OH    0             27    0.00
# 21                   MD   22             26    0.85
# 22                   WI   20             26    0.77
# 23                   VA   25             25    1.00
# 24                   FL   23             25    0.92
# 25                   MD   25             25    1.00
# 26                   MD   24             24    1.00
# 27                   FL   22             24    0.92
# 28                   AK    1             23    0.04
# 29                   KY   20             22    0.91
# 30                   MA   17             22    0.77
# 31                   GA   21             22    0.95
# 32                   FL   16             21    0.76
# 33                   TN    9             21    0.43
# 34                   GA   20             20    1.00
# 35                   OH   16             20    0.80
# 36                   CA   17             19    0.89
# 37                   SC   14             18    0.78
# 38                   NV   13             18    0.72
# 39                   TN   17             18    0.94
# 40                   AK    6             18    0.33
# 41                   MI   12             18    0.67
# 42                   FL   17             18    0.94
# 43                   CT    9             17    0.53
# 44                   FL   14             17    0.82
# 45                   GA   17             17    1.00
# 46                   TX   17             17    1.00
# 47                   NC   12             16    0.75
# 48                   FL   15             16    0.94
# 49                   CT    2             16    0.12
# 50                   GA   16             16    1.00
# 51                   GA   16             16    1.00
# 52                   LA   12             15    0.80
# 53                   VA   15             15    1.00
# 54                   DC   15             15    1.00
# 55                   NY   10             15    0.67
# 56                   SC   14             15    0.93
# 57                   TN   14             15    0.93
# 58                   MO   13             14    0.93
# 59                   AK    0             14    0.00
# 60                   FL   13             14    0.93
# 61                   AK   10             14    0.71
# 62                   NJ   12             14    0.86
# 63                   LA   11             14    0.79
# 64                   NM   13             14    0.93
# 65                   NC   11             14    0.79
# 66                   OH   14             14    1.00
# 67                   CA   13             13    1.00
# 68                   NY   10             13    0.77
# 69                   AZ   12             13    0.92
# 70                   AK    7             13    0.54
# 71                   GA   11             13    0.85
# 72                   SC   11             13    0.85
# 73                   MD   13             13    1.00
# 74                   AL   11             12    0.92
# 75                   NC   10             12    0.83
# 76                   AL   12             12    1.00
# 77                   TX   11             12    0.92
# 78                   AK    1             12    0.08
# 79                   MD   12             12    1.00
# 80                   VA   12             12    1.00
# 81                   CO    6             12    0.50
# 82                   WA   10             12    0.83
# 83                   TX   12             12    1.00
# 84                   AK    0             11    0.00
# 85                   FL    8             11    0.73
# 86                   LA   10             11    0.91
# 87                   TX   11             11    1.00
# 88                   CA   11             11    1.00
# 89                   GA   11             11    1.00
# 90                   GA   10             11    0.91
# 91                   LA   11             11    1.00
# 92                   TX   11             11    1.00
# 93                   CO   11             11    1.00
# 94                   NC   10             11    0.91
# 95                   VA   11             11    1.00
# 96                   CA   11             11    1.00
# 97                   TN    8             11    0.73
# 98                   CA   11             11    1.00
# 99                   NC   10             11    0.91

# %%
"""Top 25 Districts at Offering AP?"""
ap_by_district.drop(['No'], axis = 1).sort_values(['Total Schools'], ascending = False).reset_index(drop = True).head(100).sort_values('pct_ap', ascending = False).reset_index(drop=True).head(25)
# Out:
# SCH_APENR_IND    LEAID                                 LEA_NAME LEA_STATE  \
# 0              1301290                              Cobb County        GA
# 1               101920                         Jefferson County        AL
# 2              4808940                               AUSTIN ISD        TX
# 3              5101260                     FAIRFAX CO PBLC SCHS        VA
# 4              2400480         Montgomery County Public Schools        MD
# 5              5102250                     LOUDOUN CO PBLC SCHS        VA
# 6              5103840                  VA BEACH CITY PBLC SCHS        VA
# 7              2400420             Howard County Public Schools        MD
# 8              1302550                          Gwinnett County        GA
# 9               616230                     Grossmont Union High        CA
# 10             2400060       Anne Arundel County Public Schools        MD
# 11              638640                    Sweetwater Union High        CA
# 12             3904375                          Cincinnati City        OH
# 13             1300120                   Atlanta Public Schools        GA
# 14             4819700                           FORT WORTH ISD        TX
# 15             1100030      District of Columbia Public Schools        DC
# 16             4819650                            FORT BEND ISD        TX
# 17             2400120          Baltimore County Public Schools        MD
# 18             1301230                           Clayton County        GA
# 19             2200330                         Calcasieu Parish        LA
# 20              611820     East Side Union High School District        CA
# 21             06CC366                 Green Dot Public Schools        CA
# 22             5103130              PRINCE WILLIAM CO PBLC SCHS        VA
# 23              803450  Douglas County School District No. Re 1        CO
# 24             4833120                            NORTHSIDE ISD        TX
#
# SCH_APENR_IND  Yes  Total Schools  pct_ap
# 0               16             16     1.0
# 1               12             12     1.0
# 2               12             12     1.0
# 3               25             25     1.0
# 4               25             25     1.0
# 5               15             15     1.0
# 6               12             12     1.0
# 7               12             12     1.0
# 8               20             20     1.0
# 9               11             11     1.0
# 10              13             13     1.0
# 11              13             13     1.0
# 12              14             14     1.0
# 13              17             17     1.0
# 14              17             17     1.0
# 15              15             15     1.0
# 16              11             11     1.0
# 17              24             24     1.0
# 18              11             11     1.0
# 19              11             11     1.0
# 20              11             11     1.0
# 21              11             11     1.0
# 22              11             11     1.0
# 23              11             11     1.0
# 24              11             11     1.0

# %%
"""Bottom 25 Districts at Offering AP?"""
ap_by_district.drop(['No'], axis = 1).sort_values(['Total Schools'], ascending = False).reset_index(drop = True).head(100).sort_values('pct_ap', ascending = True).reset_index(drop=True).head(25)
# Out:
# SCH_APENR_IND    LEAID                                    LEA_NAME LEA_STATE  \
# 0              3904378      Cleveland Metropolitan School District        OH
# 1               200485  Lake and Peninsula Borough School District        AK
# 2               200020               Bering Strait School District        AK
# 3               200001             Lower Kuskokwim School District        AK
# 4               200625    Northwest Arctic Borough School District        AK
# 5               900002    Connecticut Technical High School System        CT
# 6               200390     Kenai Peninsula Borough School District        AK
# 7              4701590                             Hamilton County        TN
# 8               800020              State Charter School Institute        CO
# 9               901920                    HARTFORD SCHOOL DISTRICT        CT
# 10              200510   Matanuska-Susitna Borough School District        AK
# 11             4700148                       Shelby County Schools        TN
# 12             2400090               Baltimore City Public Schools        MD
# 13              634320                           San Diego Unified        CA
# 14             1500030              Hawaii Department of Education        HI
# 15             3605850                BUFFALO CITY SCHOOL DISTRICT        NY
# 16             2612000                Detroit City School District        MI
# 17             3620580                NEW YORK CITY PUBLIC SCHOOLS        NY
# 18              200180                   Anchorage School District        AK
# 19             3200480               WASHOE COUNTY SCHOOL DISTRICT        NV
# 20             4704020                               Sumner County        TN
# 21             1201470                                     OSCEOLA        FL
# 22              804800    Jefferson County School District No. R-1        CO
# 23             3701500        Winston Salem/Forsyth County Schools        NC
# 24             1201590                                        POLK        FL
#
# SCH_APENR_IND  Yes  Total Schools  pct_ap
# 0                0             27    0.00
# 1                0             11    0.00
# 2                0             14    0.00
# 3                1             23    0.04
# 4                1             12    0.08
# 5                2             16    0.12
# 6                6             18    0.33
# 7                9             21    0.43
# 8                6             12    0.50
# 9                9             17    0.53
# 10               7             13    0.54
# 11              26             42    0.62
# 12              23             37    0.62
# 13              25             39    0.64
# 14              42             63    0.67
# 15              10             15    0.67
# 16              12             18    0.67
# 17             314            460    0.68
# 18              10             14    0.71
# 19              13             18    0.72
# 20               8             11    0.73
# 21               8             11    0.73
# 22              21             28    0.75
# 23              12             16    0.75
# 24              16             21    0.76

# %% [markdown]
# <div class = 'alert alert-cell alert-danger'>**Visualizations**</div>

# %%
"""Distribution of AP-Offering Percentages sorted by largest to smallest districts (top 100), so left-x-axis have the
largest districts, and right-x-axis have the smallest."""
fig, (ax1, ax2) = plt.subplots(2,1, figsize=(10,9))

plt.sca(ax1)
hs_by_district.drop(['No'], axis = 1).sort_values('Total Schools', ascending = False).reset_index().drop(['index'], axis = 1).head(100)['pct_de'].plot.bar(ax=ax1)
plt.xticks([])
plt.title('DE-Offering Percentages of the Top 100 Districts')

plt.sca(ax2)
ap_by_district.drop(['No'], axis = 1).sort_values('Total Schools', ascending = False).reset_index(drop = True).head(100)['pct_ap'].plot.bar(ax=ax2)
plt.xticks([])
plt.title('AP-Offering Percentages of the Top 100 Districts')
# Out:
# Text(0.5,1,'AP-Offering Percentages of the Top 100 Districts')

# %%
fig, (ax1, ax2) = plt.subplots(2,1, figsize = (10,9))
plt.sca(ax1)
hs_by_district.drop(['No'], axis = 1).sort_values(['Total Schools'], ascending = False).reset_index(drop=True).head(100).sort_values('pct_de', ascending = False)['pct_de'].plot.bar(ax=ax1)
plt.xticks([])
plt.title('DE-Offering Percentages of the Top 100 Districts\n(Sorted By DE_PCT)')

plt.sca(ax2)
ap_by_district.drop(['No'], axis = 1).sort_values('Total Schools', ascending = False).reset_index(drop = True).head(100).sort_values('pct_ap', ascending = False)['pct_ap'].plot.bar(ax=ax2)
plt.xticks([])
plt.title('AP-Offering Percentages of the Top 100 Districts\n(Sorted By AP_PCT)')
# Out:
# Text(0.5,1,'AP-Offering Percentages of the Top 100 Districts\n(Sorted By AP_PCT)')

# %% [markdown]
# # - ScatterGeo

# %%
de_map = {'Yes':1, 'No':0}
dual_enroll_bin = hs.SCH_DUAL_IND.map(de_map)

# %%
# scl = [ [0,"rgb(5, 10, 172)"], [1,"rgb(0, 200, 100)"] ]


# data = [ dict(
#         type = 'scattergeo',
#         locationmode = 'USA-states',
#         lon = hs['LON1516'],
#         lat = hs['LAT1516'],
#         mode = 'markers',
#         marker = dict(
#             size = 5,
#             opacity = 0.8,
#             autocolorscale = False,
#             line = dict(
#                 width=1,
#                 color='rgba(255,255,255,1)'
#             ),
#             colorscale = scl,
#             cmin = 0,
#             color = dual_enroll_bin,
#             cmax = 1,
#         ))]

# layout = dict(
#         geo = dict(
#             scope='usa',
#             projection=dict( type='albers usa' ),
            
#         ),
#     )

# fig = dict( data=data, layout=layout )
# # fig = go.Figure(data = [data], layout = layout)
# iplot(fig, image = 'png', filename = '02_ScatterGeo_DE_1516', image_width = 2750, image_height=2500)

print("To see the scattergeo, uncomment code and change the size of the markers (to 3-5) -- Very cumbersome Graph")
# Out:
# To see the scattergeo, uncomment code and change the size of the markers (to 3-5) -- Very cumbersome Graph

# %% [markdown]
# # By State

# %% [markdown]
# <div class = 'alert alert-cell alert-info'>**DE**</div>

# %%
de_by_state = hs.groupby(['LEA_STATE', 'SCH_DUAL_IND'])['LEAID'].count().unstack().reset_index()
de_by_state['Total Schools'] = (de_by_state['Yes'] + de_by_state['No'])
de_by_state['pct'] = round(de_by_state['Yes'] / (de_by_state['Yes'] + de_by_state['No']), 2)

# %%
display(de_by_state.drop(['No'], axis = 1).sort_values('pct', ascending=False))
de_by_state_pcts = de_by_state[['LEA_STATE', 'pct']]
# %store de_by_state_pcts
# Out:
# SCH_DUAL_IND LEA_STATE   Yes  Total Schools   pct
# 12                  IA   321            330  0.97
# 40                  SC   212            229  0.93
# 11                  HI    57             63  0.90
# 10                  GA   379            421  0.90
# 9                   FL   504            566  0.89
# 32                  NM   148            166  0.89
# 46                  VT    57             64  0.89
# 45                  VA   287            321  0.89
# 13                  ID   133            152  0.88
# 24                  MO   481            549  0.88
# 43                  TX  1291           1487  0.87
# 18                  LA   273            313  0.87
# 28                  ND   136            157  0.87
# 29                  NE   219            259  0.85
# 16                  KS   280            331  0.85
# 1                   AL   298            353  0.84
# 15                  IN   317            378  0.84
# 41                  SD   130            155  0.84
# 42                  TN   292            352  0.83
# 22                  MI   562            675  0.83
# 17                  KY   191            232  0.82
# 20                  MD   177            218  0.81
# 5                   CO   288            360  0.80
# 44                  UT   123            156  0.79
# 48                  WI   373            481  0.78
# 14                  IL   518            671  0.77
# 2                   AR   210            273  0.77
# 35                  OH   682            895  0.76
# 50                  WY    58             76  0.76
# 25                  MS   194            263  0.74
# 27                  NC   386            537  0.72
# 49                  WV    86            121  0.71
# 23                  MN   298            432  0.69
# 36                  OK   309            445  0.69
# 37                  OR   185            270  0.69
# 8                   DE    25             36  0.69
# 47                  WA   235            365  0.64
# 6                   CT   132            206  0.64
# 38                  PA   434            677  0.64
# 31                  NJ   264            410  0.64
# 21                  ME    73            120  0.61
# 30                  NH    54             90  0.60
# 26                  MT    99            167  0.59
# 39                  RI    31             55  0.56
# 19                  MA   159            349  0.46
# 34                  NY   546           1220  0.45
# 3                   AZ   180            402  0.45
# 33                  NV    52            115  0.45
# 0                   AK    97            243  0.40
# 4                   CA   488           1432  0.34
# 7                   DC     6             29  0.21
# Stored 'de_by_state_pcts' (DataFrame)

# %%
de_data = dict(type = 'choropleth',
            locations = de_by_state['LEA_STATE'],
            locationmode = 'USA-states',
            colorscale = [[0.0, 'rgb(255,255,255)'], [.2, 'rgb(255,221,221)'], [.4, 'rgb(255, 200, 200)'], [0.8, 'rgb(255, 50, 50)'], [1.0, 'rgb(180,0,0)']],
            reversescale = False,
            z = de_by_state['pct'])

# %%
de_layout = dict(title = '2015-2016 DE-Offered Percentages',
              geo = {'scope':'usa'})

# %%
de_choromap = go.Figure(data = [de_data], layout = de_layout)

# %%
iplot(de_choromap)
# iplot(de_choromap, image = 'png', filename='./Visualizations/by_state_de_choropleth')
# Out:
# <div id="f2a406c4-e1e4-4954-83d2-cb4524117b06" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f2a406c4-e1e4-4954-83d2-cb4524117b06", [{"type": "choropleth", "locations": ["AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY"], "locationmode": "USA-states", "colorscale": [[0.0, "rgb(255,255,255)"], [0.2, "rgb(255,221,221)"], [0.4, "rgb(255, 200, 200)"], [0.8, "rgb(255, 50, 50)"], [1.0, "rgb(180,0,0)"]], "reversescale": false, "z": [0.4, 0.84, 0.77, 0.45, 0.34, 0.8, 0.64, 0.21, 0.69, 0.89, 0.9, 0.9, 0.97, 0.88, 0.77, 0.84, 0.85, 0.82, 0.87, 0.46, 0.81, 0.61, 0.83, 0.69, 0.88, 0.74, 0.59, 0.72, 0.87, 0.85, 0.6, 0.64, 0.89, 0.45, 0.45, 0.76, 0.69, 0.69, 0.64, 0.56, 0.93, 0.84, 0.83, 0.87, 0.79, 0.89, 0.89, 0.64, 0.78, 0.71, 0.76]}], {"title": "2015-2016 DE-Offered Percentages", "geo": {"scope": "usa"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# <div class = 'alert alert-cell alert-warning'>**AP**</div>

# %%
ap_by_state = hs.groupby(['LEA_STATE', 'SCH_APENR_IND'])['LEAID'].count().unstack().reset_index()
"""Fill in Missing Values with 0"""
ap_by_state = ap_by_state.fillna(0)
ap_by_state[['Yes', 'No']] = ap_by_state[['Yes', 'No']].astype(int)
ap_by_state['Total Schools'] = (ap_by_state['Yes'] + ap_by_state['No'])
ap_by_state['pct'] = round(ap_by_state['Yes'] / (ap_by_state['Yes'] + ap_by_state['No']), 2)

# %%
display(ap_by_state.drop(['No'], axis = 1).sort_values('pct', ascending=False))
ap_by_state_pcts = ap_by_state[['LEA_STATE', 'pct']]
# %store ap_by_state_pcts
# Out:
# SCH_APENR_IND LEA_STATE   Yes  Total Schools   pct
# 7                    DC    28             29  0.97
# 45                   VA   299            321  0.93
# 2                    AR   255            273  0.93
# 31                   NJ   377            410  0.92
# 20                   MD   200            218  0.92
# 49                   WV   109            121  0.90
# 10                   GA   376            421  0.89
# 15                   IN   328            378  0.87
# 17                   KY   202            232  0.87
# 19                   MA   295            349  0.85
# 9                    FL   482            566  0.85
# 38                   PA   566            677  0.84
# 46                   VT    53             64  0.83
# 21                   ME   100            120  0.83
# 6                    CT   171            206  0.83
# 8                    DE    30             36  0.83
# 48                   WI   394            481  0.82
# 40                   SC   186            229  0.81
# 30                   NH    73             90  0.81
# 4                    CA  1163           1432  0.81
# 39                   RI    44             55  0.80
# 27                   NC   424            537  0.79
# 34                   NY   932           1220  0.76
# 43                   TX  1078           1487  0.72
# 47                   WA   262            365  0.72
# 33                   NV    79            115  0.69
# 44                   UT   106            156  0.68
# 11                   HI    42             63  0.67
# 22                   MI   448            675  0.66
# 14                   IL   441            671  0.66
# 1                    AL   226            353  0.64
# 5                    CO   230            360  0.64
# 18                   LA   196            313  0.63
# 25                   MS   161            263  0.61
# 42                   TN   202            352  0.57
# 35                   OH   501            895  0.56
# 36                   OK   240            445  0.54
# 37                   OR   139            270  0.51
# 12                   IA   168            330  0.51
# 32                   NM    79            166  0.48
# 3                    AZ   191            402  0.48
# 26                   MT    77            167  0.46
# 23                   MN   191            432  0.44
# 24                   MO   223            549  0.41
# 41                   SD    62            155  0.40
# 13                   ID    60            152  0.39
# 50                   WY    29             76  0.38
# 16                   KS    94            331  0.28
# 29                   NE    67            259  0.26
# 28                   ND    35            157  0.22
# 0                    AK    42            243  0.17
# Stored 'ap_by_state_pcts' (DataFrame)

# %%
ap_data = dict(type = 'choropleth',
            locations = ap_by_state['LEA_STATE'],
            locationmode = 'USA-states',
            colorscale = [[0.0, 'rgb(255,255,255)'], [.2, 'rgb(255,221,221)'], [.4, 'rgb(255, 200, 200)'], [0.8, 'rgb(255, 50, 50)'], [1.0, 'rgb(180,0,0)']],
            reversescale = False,
            z = ap_by_state['pct'])

# %%
ap_layout = dict(title = '2015-2016 AP-Offered Percentages',
              geo = {'scope':'usa'})

# %%
ap_choromap = go.Figure(data = [ap_data], layout = ap_layout)

# %%
iplot(ap_choromap)
# iplot(ap_choromap, image = 'png', filename='./Visualizations/by_state_ap_choropleth')
# Out:
# <div id="e5c9c676-1963-4c62-829f-4d4df6710d51" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e5c9c676-1963-4c62-829f-4d4df6710d51", [{"type": "choropleth", "locations": ["AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY"], "locationmode": "USA-states", "colorscale": [[0.0, "rgb(255,255,255)"], [0.2, "rgb(255,221,221)"], [0.4, "rgb(255, 200, 200)"], [0.8, "rgb(255, 50, 50)"], [1.0, "rgb(180,0,0)"]], "reversescale": false, "z": [0.17, 0.64, 0.93, 0.48, 0.81, 0.64, 0.83, 0.97, 0.83, 0.85, 0.89, 0.67, 0.51, 0.39, 0.66, 0.87, 0.28, 0.87, 0.63, 0.85, 0.92, 0.83, 0.66, 0.44, 0.41, 0.61, 0.46, 0.79, 0.22, 0.26, 0.81, 0.92, 0.48, 0.69, 0.76, 0.56, 0.54, 0.51, 0.84, 0.8, 0.81, 0.4, 0.57, 0.72, 0.68, 0.93, 0.83, 0.72, 0.82, 0.9, 0.38]}], {"title": "2015-2016 AP-Offered Percentages", "geo": {"scope": "usa"}}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# # By Region

# %% [markdown]
# <div class = 'alert alert-cell alert-danger'>**Create a Region Classifer based on Region Accreditation**</div>

# %%
"""
1:  Middle States Commission on Higher Education - New York, New Jersey, Pennsylvania, Delaware, Maryland, the District of Columbia

2:  New England Association of Schools and Colleges - Connecticut, Maine, Massachusetts, New Hampshire, Rhode Island, and Vermont

3:  Higher Learning Commission - Arkansas, Arizona, Colorado, Iowa, Illinois, Indiana, Kansas, Michigan, Minnesota, Missouri, 
    North Dakota, Nebraska, New Mexico, Ohio, Oklahoma, South Dakota, Wisconsin, West Virginia, and Wyoming

4:  Northwest Commission on Colleges and Universities - Alaska, Idaho, Montana, Nevada, Oregon, Utah, and Washington

5:  Southern Association of Colleges and Schools - Alabama, Florida, Georgia, Kentucky, Louisiana, Mississippi, 
    North Carolina, South Carolina, Tennessee, Texas and Virginia

6:  Western Association of Schools and Colleges - California, Hawaii
"""

from my_functions.extra_functions import region_mapper
hs['region_accred'] = hs['LEA_STATE'].apply(lambda x: region_mapper(x))

# %%
sns.lmplot(x = 'LON1516', y = 'LAT1516', data = hs, hue = 'region_accred', fit_reg = False, aspect = 1.2)
# plt.savefig(fname = './Visualizations/By_regionII_map_200.png', dpi = 200)

# %% [markdown]
# <div class = 'alert alert-cell alert-info'>**DE**</div>

# %%
de_by_region_accred = hs.groupby(['region_accred', 'SCH_DUAL_IND'])['LEA_STATE'].count().unstack('SCH_DUAL_IND').reset_index()
de_by_region_accred['Total Schools'] = (de_by_region_accred['Yes'] + de_by_region_accred['No'])
de_by_region_accred['pct_de'] = round(de_by_region_accred['Yes'] / (de_by_region_accred['Yes'] + de_by_region_accred['No']), 2)
display(de_by_region_accred.drop(['No'], axis = 1))

# %store de_by_region_accred
# Out:
# SCH_DUAL_IND region_accred   Yes  Total Schools  pct_de
# 0                      HLC  5596           7156    0.78
# 1                    MSCHE  1452           2590    0.56
# 2                    NEASC   506            884    0.57
# 3                    NWCCU   924           1468    0.63
# 4                     SACS  4307           5074    0.85
# 5                     WASC   545           1495    0.36
# Stored 'de_by_region_accred' (DataFrame)

# %% [markdown]
# <div class = 'alert alert-cell alert-warning'>**AP**</div>

# %%
ap_by_region_accred = hs.groupby(['region_accred', 'SCH_APENR_IND'])['LEA_STATE'].count().unstack().reset_index()
ap_by_region_accred['Total Schools'] = (ap_by_region_accred['Yes'] + ap_by_region_accred['No'])
ap_by_region_accred['pct_ap'] = round(ap_by_region_accred['Yes'] / (ap_by_region_accred['Yes'] + ap_by_region_accred['No']), 2)
display(ap_by_region_accred.drop(['No'], axis = 1))

# %store ap_by_region_accred
# Out:
# SCH_APENR_IND region_accred   Yes  Total Schools  pct_ap
# 0                       HLC  4085           7156    0.57
# 1                     MSCHE  2133           2590    0.82
# 2                     NEASC   736            884    0.83
# 3                     NWCCU   765           1468    0.52
# 4                      SACS  3832           5074    0.76
# 5                      WASC  1205           1495    0.81
# Stored 'ap_by_region_accred' (DataFrame)

# %% [markdown]
# <div class = 'alert alert-cell alert-danger'>**Visualizations**</div>

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize = (10,4))

plt.sca(ax1)
de_by_region_accred.plot.bar(x = 'region_accred', y = 'pct_de', ax=ax1)
plt.title('Percentage of Schools Offering DE\n by Region')
plt.xticks(rotation = 0)
plt.legend([])
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')

plt.sca(ax2)
ap_by_region_accred.plot.bar(x = 'region_accred', y = 'pct_ap', ax=ax2)
plt.title('Percentage of Schools Offering AP\n by Region')
plt.xticks(rotation = 0)
plt.legend([])
plt.yticks(np.arange(0,1.1,0.1))
plt.ylim([0,1])
plt.xlabel('')
# Out:
# Text(0.5,0,'')
